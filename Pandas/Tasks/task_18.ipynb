# %% [markdown]
# # **Task 18 - (Article 115)** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Tasks/task_18.ipynb)
#
# |🔴 **WARNING** 🔴|
# |:-----------:|
# |If you have not studied article 115. Do checkout the articles before attempting the task.|
# | Here is [Important DataFrame Methods](../Articles/115_important_dataframe_methods.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ⚠️ **Settings Warning**
#
# 1. To visulaize all the columns of the dataset, run the below code :
#     ```python
#     pd.options.display.max_columns = None
#     ```
#
# 2. To visulaize all the records of the dataset, run the below code :
#     ```python
#     pd.options.display.max_rows = None
#     ```

# %%
pd.options.display.max_columns = None

# %%
pd.options.display.max_rows = None

# %% [markdown]
# ### ⚠️ **Data Warning**
# For the questions forward, we are going to use FIFA WORLDCUP 2022 Dataset, which is imported using the direct URL of the dataset.
#
# FIFA WORLDCUP 2022 Dataset : [Link](https://www.kaggle.com/datasets/sayanroy729/fifa-worldcup-2022-results)

# %% [markdown]
# #### **Reading Data into DataFrame**

# %%
fifa_df = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/fifa_worldcup_2022.csv'
)

# %%
fifa_df.head()
# Out:
#    Sl. No  Match No.     Team      Against Group  Goal  Possession (%)  \
# 0       1          1    Qatar      Ecuador     A     0              40
# 1       2          1  Ecuador        Qatar     A     2              46
# 2       3          2  England         Iran     B     6              69
# 3       4          2     Iran      England     B     2              20
# 4       5          3  Senegal  Netherlands     A     0              39
#
#    Inside Penalty Area  Outside Penalty Area  Assists  Total Attempts  \
# 0                    0                     0        0               5
# 1                    2                     0        1               5
# 2                    6                     0        6              13
# 3                    2                     0        1               8
# 4                    0                     0        0              15
#
#    On Target  Off Target  Target in Penalty  Target from Outside  \
# ...

# %% [markdown]
# ### **🎯 Q1: Team-wise On-Target Percentage in Football Dataset**
#
# Compute the **percentage of total attempts that were on target** for each team in the dataset.
#
# 1. **Instructions:**
#    1. Identify the **total number of unique teams** that participated in the tournament.
#    2. For each team:
#       - Filter the dataset to include only matches where the team played.
#       - Calculate the **total number of attempts** and **total on-target attempts**.
#       - Compute the percentage using the formula:
#         $$
#         \text{On-Target Percentage} = \left(\frac{\text{Total On-Target Attempts}}{\text{Total Attempts}}\right) \times 100
#         $$
#       - Round the result to **2 decimal places**.
#    3. Store the values in a **Python dictionary**, where the **keys** are team names and the **values** are the computed percentages.
#    4. Sort the dictionary by **percentage values in descending order** and display the final result.
#
# 2. **Expected Output Format:**
#    - A **Python dictionary** containing team names as **keys** and their **on-target percentage** as values, **sorted** in descending order.
#    - Example Output:
#      ```python
#      {'Costa Rica': 54.55, 'Cameroon': 51.85, 'Ecuador': 48.15, ... , 'Canada': 17.65}
#      ```

# %%
# Solution - Question 01

def prepare_dict(teams, df):
    output = {}
    for i in teams:
        mask = df['Team'] == i
        total_attempts = df[mask]['Total Attempts'].sum()
        on_target_attempts = df[mask]['On Target'].sum()
        percentage = round((on_target_attempts / total_attempts) * 100, 2)
        output[i] = percentage
    return dict(sorted(output.items(), key=lambda item: item[1], reverse=True))

teams = fifa_df['Team'].unique()
prepare_dict(
    teams = teams,
    df = fifa_df
)
# Out:
# {'Costa Rica': 54.55,
#  'Cameroon': 51.85,
#  'Ecuador': 48.15,
#  'Argentina': 46.15,
#  'Brazil': 45.56,
#  'England': 45.0,
#  'Portugal': 40.32,
#  'Ghana': 40.0,
#  'Netherlands': 39.02,
#  'Korea Republic': 36.73,
#  'Australia': 36.0,
#  'Mexico': 34.88,
#  'France': 34.65,
#  'Germany': 34.33,
#  'Croatia': 33.73,
#  'Spain': 32.69,
#  'Belgium': 32.35,
#  'Serbia': 32.26,
#  'Iran': 31.43,
#  'Uruguay': 31.25,
#  'United States': 31.11,
#  'Saudi Arabia': 31.03,
#  'Senegal': 30.77,
#  'Denmark': 30.56,
#  'Switzerland': 30.56,
#  'Japan': 30.23,
#  'Wales': 29.17,
#  'Qatar': 28.57,
#  'Morocco': 28.33,
#  'Tunisia': 26.67,
#  'Poland': 25.0,
#  'Canada': 17.65}

# %% [markdown]
# ### **🎯 Q2: Team Appearances & Ranking in FIFA World Cup 2022**
#
# Determine the **number of times** each team played in the **FIFA World Cup 2022** and assign **rankings** accordingly.
#
# 1. **Instructions:**
#    1. Identify all unique teams that participated in the tournament.
#    2. Count the **total number of matches played** by each team.
#    3. Assign **ranks** to teams based on their number of matches played.
#    4. Use the `DataFrame.rank()` method to **rank teams**.
#       - By default, it uses `method="average"` (which may produce decimal values).
#       - Use `method="first"` to get **integer ranks**.
#    5. Display the results as a **table or dictionary**, showing:
#       - **Team Name**
#       - **Total Matches Played**
#       - **Rank**
#
# 2. **Expected Output Format:** (DUMMY)
#     | Team              | Matches Played | Rank |
#     |------------------|---------------|------|
#     | Argentina        | 7             | 1    |
#     | France          | 7             | 2    |
#     | Croatia         | 7             | 3    |
#     | Morocco         | 7             | 4    |
#     | ...            | ...           | ...  |

# %%
# Solution - Question 02

team_match_count = fifa_df['Team'].value_counts() + fifa_df['Against'].value_counts()
team_match_count.fillna(
    value = 1,
    inplace = True
)
team_match_count.sort_values(
    ascending = False,
    inplace = True
)
team_rank = team_match_count.rank(
    method = 'first',
    ascending = False
)
team_rank_df = pd.DataFrame(
    data = {
        'Team' : team_match_count.index,
        'Match Count' : team_match_count,
        'Rank' : team_rank
    },
).reset_index(drop=True)

team_rank_df
# Out:
#               Team  Match Count  Rank
# 0        Argentina         14.0   1.0
# 1          Croatia         14.0   2.0
# 2          Morocco         14.0   3.0
# 3           France         13.0   4.0
# 4           Brazil         10.0   5.0
# 5         Portugal         10.0   6.0
# 6          England         10.0   7.0
# 7      Netherlands         10.0   8.0
# 8        Australia          8.0   9.0
# 9    United States          8.0  10.0
# 10     Switzerland          8.0  11.0
# 11           Spain          8.0  12.0
# 12         Senegal          8.0  13.0
# 13          Poland          8.0  14.0
# 14  Korea Republic          8.0  15.0
# 15           Japan          8.0  16.0
# 16            Iran          6.0  17.0
# 17      Costa Rica          6.0  18.0
# 18         Uruguay          6.0  19.0
# 19         Belgium          6.0  20.0
# 20         Tunisia          6.0  21.0
# 21        Cameroon          6.0  22.0
# 22          Canada          6.0  23.0
# 23          Serbia          6.0  24.0
# ...

# %% [markdown]
# ### **🎯 Q3: FIFA World Cup Dataset Analysis & Cleaning**
#
# Perform the following operations on the **FIFA World Cup dataset**:
#
# 1. **Tasks to Complete:**
#
#     1️⃣ **Dataset Information:**
#     - Display **general information** about the dataset, including column names, data types, and non-null counts.
#
#     2️⃣ **Dataset Description:**
#     - Provide **statistical summaries** (such as mean, min, max, std) for numerical columns.
#
#     3️⃣ **Handling Missing Values:**
#     - Identify **missing values** in the dataset.
#     - If any missing values exist, **replace them** with the **average value** of the respective column.
#
#     4️⃣ **Removing Duplicate Rows:**
#     - Check for **duplicate rows** and remove them **permanently**.
#
#     5️⃣ **Dropping Unnecessary Columns:**
#     - **Permanently** drop the following columns:
#         - `"Sl No"`
#         - `"Match No."`
#         - `"Red Cards"`
#         - `"Pts"`
#
# 2. **Expected Output Format:**
#    - Print dataset **info()** and **describe()**.
#    - Display **missing values before and after filling**.
#    - Print the number of **duplicate rows removed**.
#    - Show the **final dataframe structure** after column removal.

# %%
# Solution - Question 03

fifa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128 entries, 0 to 127
# Data columns (total 38 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Sl. No                           128 non-null    int64
#  1   Match No.                        128 non-null    int64
#  2   Team                             128 non-null    object
#  3   Against                          128 non-null    object
#  4   Group                            128 non-null    object
#  5   Goal                             128 non-null    int64
#  6   Possession (%)                   128 non-null    int64
#  7   Inside Penalty Area              128 non-null    int64
#  8   Outside Penalty Area             128 non-null    int64
#  9   Assists                          128 non-null    int64
#  10  Total Attempts                   128 non-null    int64
#  11  On Target                        128 non-null    int64
# ...

# %%
fifa_df.describe()
# Out:
#            Sl. No   Match No.        Goal  Possession (%)  \
# count  128.000000  128.000000  128.000000      128.000000
# mean    64.500000   32.500000    1.343750       43.476562
# std     37.094474   18.545539    1.342448       11.442403
# min      1.000000    1.000000    0.000000       14.000000
# 25%     32.750000   16.750000    0.000000       35.000000
# 50%     64.500000   32.500000    1.000000       45.000000
# 75%     96.250000   48.250000    2.000000       51.000000
# max    128.000000   64.000000    7.000000       78.000000
#
#        Inside Penalty Area  Outside Penalty Area     Assists  Total Attempts  \
# count           128.000000            128.000000  128.000000      128.000000
# mean              1.203125              0.117188    0.914062       11.257812
# std               1.324270              0.322907    1.150333        5.406683
# min               0.000000              0.000000    0.000000        0.000000
# ...

# %%
fifa_df.isnull().sum()
# Out:
# Sl. No                             0
# Match No.                          0
# Team                               0
# Against                            0
# Group                              0
# Goal                               0
# Possession (%)                     0
# Inside Penalty Area                0
# Outside Penalty Area               0
# Assists                            0
# Total Attempts                     0
# On Target                          0
# Off Target                         0
# Target in Penalty                  0
# Target from Outside                0
# Left Channel                       0
# Left Inside Channel                0
# Central Channel                    0
# Right Inside Channel               0
# Right Channel                      0
# Receptions MD                      0
# Receptions D                       0
# Attempted Line Breaks              0
# Completed Line Breaks              0
# Attempted Defensive Line Breaks    0
# ...

# %%
fifa_df.duplicated().sum()
# Out:
# 0

# %%
fifa_df.drop(
    columns = ['Sl. No', 'Match No.', 'Red Cards', 'Pts'],
    inplace = True
)
fifa_df.columns
# Out:
# Index(['Team', 'Against', 'Group', 'Goal', 'Possession (%)',
#        'Inside Penalty Area', 'Outside Penalty Area', 'Assists',
#        'Total Attempts', 'On Target', 'Off Target', 'Target in Penalty',
#        'Target from Outside', 'Left Channel', 'Left Inside Channel',
#        'Central Channel', 'Right Inside Channel', 'Right Channel',
#        'Receptions MD', 'Receptions D', 'Attempted Line Breaks',
#        'Completed Line Breaks', 'Attempted Defensive Line Breaks',
#        'Completed Defensive Line Breaks', 'Yellow Cards', 'Fouls Against',
#        'Offsides', 'Passes', 'Passes Completed', 'Crosses',
#        'Crosses Completed', 'Corners', 'Free Kicks', 'Penalties Scored'],
#       dtype='object')

# %% [markdown]
# ### **🎯 Q4: Ranking Teams in FIFA World Cup Dataset**
#
# Perform the following operations on the **FIFA World Cup dataset**:
#
# 1. **Tasks to Complete:**
#
#     1️⃣ **Rank Teams:**
#     - Compute the **rank** of each team based on the `"Team"` column.
#     - Save this result in a **new column** named `"Rank"`.
#
#     2️⃣ **Change Data Type:**
#     - Convert the `"Rank"` column to **integer** using `np.int16`.
#
#     3️⃣ **Set Index:**
#     - **Permanently** set the `"Rank"` column as the **index** of the DataFrame.
#
#     4️⃣ **Sort DataFrame:**
#     - Sort the **DataFrame** based on the **"Rank" index**.
#
# 2. **Expected Output Format:**
#    - Display **updated DataFrame** after ranking and sorting.
#    - Print **data types** to confirm `"Rank"` is converted correctly.
#    - Show the **final DataFrame structure** with `"Rank"` as the index.

# %%
# Solution - Question 04

fifa_df['Rank'] = fifa_df['Team'].rank(method='first')

fifa_df['Rank'] = fifa_df['Rank'].astype(np.int16)

fifa_df.set_index(
    keys = 'Rank',
    inplace = True
)

fifa_df.sort_index()
# Out:
#                 Team         Against Group  Goal  Possession (%)  \
# Rank
# 1          Argentina    Saudi Arabia     C     1              51
# 2          Argentina          Mexico     C     2              50
# 3          Argentina          Poland     C     2              67
# 4          Argentina       Australia     C     2              53
# 5          Argentina     Netherlands     C     2              44
# 6          Argentina         Croatia     C     3              34
# 7          Argentina          France     C     3              46
# 8          Australia          France     D     1              35
# 9          Australia         Tunisia     D     1              31
# 10         Australia         Denmark     D     1              24
# 11         Australia       Argentina     D     1              35
# 12           Belgium          Canada     F     1              46
# 13           Belgium         Morocco     F     0              55
# ...

# %% [markdown]
# ### ⚠️ **Data Warning**
# For the questions forward, we are going to use TITANIC DataSet, which is in the [Resources](../Resources/) folder.
#
# TITANIC Dataset : In the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrame**

# %%
titanic_train_df = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/titanic_train_dataset.csv'
)

# %%
titanic_train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_test_df = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/titanic_test_dataset.csv'
)

# %%
titanic_test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### **🎯 Q5: Handling Missing Values in Titanic Datasets**
#
# Perform the following operations on the **Titanic datasets**:
#
# 1. **Tasks to Complete:**
#
#     1️⃣ **For `titanic_train_dataset`**
#     - **Drop** all rows where the `"Age"` column has **missing values**.
#     - Ensure the **changes are permanent**.
#
#     2️⃣ **For `titanic_test_dataset`**
#     - **Fill** missing values in the `"Age"` column with **20**.
#     - Ensure the **changes are permanent**.
#
# 2. **Expected Output Format:**
#    - Print the **shape** of datasets **before and after** modifications.
#    - Display a **summary** to confirm missing values are handled.
#    - Show a **few rows** to verify the applied changes.

# %%
titanic_train_df['Age'].isna().sum()
# Out:
# 177

# %%
titanic_train_df.shape
# Out:
# (891, 12)

# %%
titanic_train_df.dropna(
    subset = 'Age',
    inplace = True
)

# %%
titanic_train_df['Age'].isna().sum()
# Out:
# 0

# %%
titanic_train_df.shape
# Out:
# (714, 12)

# %%
titanic_test_df['Age'].isna().sum()
# Out:
# 86

# %%
titanic_test_df.shape
# Out:
# (418, 11)

# %%
titanic_test_df.fillna(
    value = 20,
    inplace = True
)

# %%
titanic_test_df.shape
# Out:
# (418, 11)

# %%
titanic_test_df['Age'].isna().sum()
# Out:
# 0

# %% [markdown]
# ### ⚠️ **Data Warning**
# For the questions forward, we are going to use ipl_matches DataSet, which is in the [Resources](../Resources/) folder.
#
# IPL Dataset : In the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrame**

# %%
ipl_df = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/ipl-matches.csv'
)
ipl_df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %% [markdown]
# ### **🎯 Q6: IPL Team Performance Analysis**
#
# Create a **DataFrame** for each **IPL team** with the following details:
#
# 1. **📝 Required Columns:**
#   1️⃣ **Team Name**
#   2️⃣ **Matches Played**
#   3️⃣ **Win %** *(Overall Winning Percentage)*
#   4️⃣ **Home Win %** *(Winning Percentage in Home Matches)*
#   5️⃣ **Away Win %** *(Winning Percentage in Away Matches)*
#
# 2. **📌 Important Notes:**
#    - Replace **old team names** with their **new names** before performing any calculations:
#       ```
#       Delhi Daredevils → Delhi Capitals
#       Kings XI Punjab → Punjab Kings
#       Rising Pune Supergiants → Rising Pune Supergiant
#       ```
#    - **Team1** represents the **Home Team**.
#    - Exclude matches that had **no result**.
#    - Sort the final **DataFrame** based on **Win %** in **descending order**.
#
# 3. **✅ Expected Output Format:**
#    - A **sorted DataFrame** showing each team's **performance statistics**.
#    - Display a **few rows** to verify correctness.

# %%
ipl_df.replace(
    to_replace = {
        'Delhi Daredevils' : 'Delhi Capitals',
        'Kings XI Punjab' : 'Punjab Kings',
        'Rising Pune Supergiants' : 'Rising Pune Supergiant'
    },
    inplace = True
)

# %%
all_teams = np.unique(
    np.append(
        ipl_df['Team1'].unique(),
        ipl_df['Team2'].unique()
    )
)
matches_df = ipl_df[~ipl_df.WinningTeam.isna()]

# %%
data = []
for team in all_teams:
    match_count = matches_df[(matches_df['Team1'] == team) | (matches_df['Team2'] == team)].shape[0]
    winning_count = matches_df[(matches_df['WinningTeam'] == team)].shape[0]
    winning_percentage = round((winning_count / match_count) * 100, 2)

    home_matches_count = matches_df[(matches_df['Team1'] == team)].shape[0]
    home_win_count = matches_df[(matches_df['Team1'] == team) & (matches_df['WinningTeam'] == team)].shape[0]
    home_winning_percentage = round((home_win_count / home_matches_count) * 100, 2)

    away_matches_count = matches_df[(matches_df['Team2'] == team)].shape[0]
    away_win_count = matches_df[(matches_df['Team2'] == team) & (matches_df['WinningTeam'] == team)].shape[0]
    away_winning_percentage = round((away_win_count / away_matches_count) * 100, 2)
    
    data.append(
        [
            team,
            match_count,
            winning_percentage,
            home_winning_percentage,
            away_winning_percentage
        ]
    )

team_performance_df = pd.DataFrame(
    data = data,
    columns = ['Team Name', 'Matches Played', 'Win %', 'Home Win %', 'Away Win %']
)

# %%
team_performance_df.sort_values(
    by = 'Win %',
    ascending = False
)
# Out:
#                       Team Name  Matches Played  Win %  Home Win %  Away Win %
# 4                Gujarat Titans              16  75.00       57.14       88.89
# 7          Lucknow Super Giants              15  60.00       87.50       28.57
# 0           Chennai Super Kings             208  58.17       58.56       57.73
# 8                Mumbai Indians             231  56.71       58.04       55.46
# 6         Kolkata Knight Riders             223  51.12       53.33       49.15
# 11             Rajasthan Royals             190  50.53       55.06       46.53
# 12       Rising Pune Supergiant              30  50.00       50.00       50.00
# 14          Sunrisers Hyderabad             152  49.34       52.17       46.99
# 13  Royal Challengers Bangalore             223  48.88       49.59       48.00
# 2                Delhi Capitals             222  46.40       46.90       45.87
# 10                 Punjab Kings             218  46.33       45.45       47.22
# ...

# %% [markdown]
# ### **🎯 Q7: Venues with Most "No Result" Matches**
#
# Find out the **venues** where the highest number of **"No Result"** matches occurred in IPL history.
#
# 1. **📌 Key Points:**
#    - A **"No Result"** match is a game that was abandoned or did not have a clear winner.
#    - Identify **venues** with the most such occurrences.
#    - Display the **top venues** sorted in **descending order** based on the number of "No Result" matches.
#
# 2. **✅ Expected Output Format:**
#    - A **sorted list or DataFrame** showing venues with their **count of "No Result" matches**.
#    - Display the **top results** to verify correctness.

# %%
ipl_df[ipl_df['WonBy'] == 'NoResults']['Venue'].value_counts()
# Out:
# Venue
# M Chinnaswamy Stadium    2
# M.Chinnaswamy Stadium    1
# Feroz Shah Kotla         1
# Name: count, dtype: int64

# %% [markdown]
# ### **🎯 Q8: Player with Most Appearances in Final Matches**
#
# Find out the **player** who has appeared the most times in IPL **final matches**.
#
# 1. **📌 Key Points:**
#    - The **final match** is the last match of each IPL season.
#    - Player names are stored in the **"Team1Players"** and **"Team2Players"** columns as a **single string** (not a list).
#    - Use **string manipulation techniques** (e.g., `split()` and `strip()`) to extract individual player names.
#    - Count **the number of times** each player appeared in a final match.
#
# 2. **✅ Expected Output Format:**
#    - Display the **player with the highest appearances in IPL finals** along with their **count**.
#    - Show the **top players** sorted in **descending order** based on appearances.

# %%
final_matches = ipl_df[ipl_df['MatchNumber'] == 'Final']

# %%
def extract_players(team_players):
    players = team_players.split(',')
    players = list(
        map(
            lambda x : x.strip('[]\' '),
            players
        )
    )
    return pd.Series(players)

# %%
players_series = pd.Series()
for team in final_matches.Team1Players:
    players_series = pd.concat(
        objs = [
            players_series,
            extract_players(team)
        ]
    )
for team in final_matches.Team2Players:
    players_series = pd.concat(
        objs = [
            players_series,
            extract_players(team)
        ]
    )

# %%
players_series.value_counts().head()
# Out:
# MS Dhoni     10
# SK Raina      8
# AT Rayudu     7
# R Ashwin      7
# DJ Bravo      7
# Name: count, dtype: int64

# %% [markdown]
# ### **🎯 Q9: IPL Points Table**
#
# Create a function **`point_table(season)`** that generates the **IPL Points Table** for a given season.
#
# 1. **📌 Function Behavior:**
#    - The function takes **one parameter**:
#      ```python
#      point_table(season: str)
#      ```
#    - The `season` must be one of the following valid season names:
#      ```python
#      ['2022', '2021', '2020/21', '2019', '2018', '2017', '2016',
#       '2015', '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08']
#      ```
#
# 2. **✅ Points System:**
#    - **Win** → +2 Points
#    - **Loss** → +0 Points
#    - **No Result** → +1 Point per team
#
# 3. **📊 Required DataFrame Structure:**
#     | **TeamName**        | **MatchesPlayed** | **MatchesWon** | **NoResult** | **Points** |
#     |----------------------|------------------|---------------|------------|----------|
#     | Gujarat Titans      | 16               | 12            | 0          | 24       |
#     | Rajasthan Royals    | 17               | 10            | 0          | 20       |
#
# 4. **📌 Sorting Criteria:**
#    1. **Sort by "Points" in descending order** (highest points first).
#    2. **If teams have the same points, sort by "TeamName" in ascending order** (A → Z).
#
# 5. **⚠️ Additional Notes:**
#    - **Exclude abandoned seasons** if any.
#    - **Make "TeamName" the index** in the DataFrame.
#
# 🚀 Call Example:
# ```python
# point_table('2022')
# ```

# %%
def point_table(season : str):
    season_matches = ipl_df[ipl_df.Season == season]
    all_teams = np.unique(
        np.append(
            season_matches['Team1'].unique(),
            season_matches['Team2'].unique()
        )
    )
    points_data = []
    for team in all_teams:
        matches_played = season_matches[(season_matches.Team1 == team) | (season_matches.Team2 == team)].shape[0]
        matches_won = season_matches[season_matches.WinningTeam == team].shape[0]
        no_result_matches = season_matches[
            season_matches.WinningTeam.isna() & 
            ((season_matches.Team1 == team) | (season_matches.Team2 == team))
            ].shape[0]
        team_points = (matches_won * 2) + (no_result_matches * 1)
        points_data.append(
            [
                team,
                matches_played,
                matches_won,
                no_result_matches,
                team_points
            ]
        )
    df = pd.DataFrame(
        data = points_data,
        columns = [
            'TeamName',
            'MatchesPlayed',
            'MathcesWon',
            'NoResult',
            'Points'
        ],
    ).sort_values(by = ['Points', 'TeamName'], ascending = [False, True]).set_index(keys = 'TeamName')

    return df

# %%
point_table('2022')
# Out:
#                              MatchesPlayed  MathcesWon  NoResult  Points
# TeamName
# Gujarat Titans                          16          12         0      24
# Rajasthan Royals                        17          10         0      20
# Lucknow Super Giants                    15           9         0      18
# Royal Challengers Bangalore             16           9         0      18
# Delhi Capitals                          14           7         0      14
# Punjab Kings                            14           7         0      14
# Kolkata Knight Riders                   14           6         0      12
# Sunrisers Hyderabad                     14           6         0      12
# Chennai Super Kings                     14           4         0       8
# Mumbai Indians                          14           4         0       8

# %% [markdown]
# ### **🎯 Q10: IPL Points Table (Extended)**
#
# Extend the **IPL Points Table** from the previous question by adding an **extra column**: `"SeasonPosition"`.
#
# 1. **📌 Column: `SeasonPosition` Rules**
#     After **sorting by**:
#     1. **"Points"** (descending order)
#     2. **"TeamName"** (ascending order)
#
# Assign the `"SeasonPosition"` as follows:
#
# 2. **🏆 Top 4 Teams**
#     | Position | Condition |
#     |----------|-----------|
#     | **Winner** | Team that won the Final |
#     | **Runner** | Team that lost the Final |
#     | **3** | Losing team in **Qualifier 2** |
#     | **4** | Losing team in **Eliminator** |
#
# 3. **📊 Other Teams**
#    - All remaining teams will have `"SeasonPosition"` **equal to their rank**, using `rank()`.
#
# 4. **✅ Updating Specific Cells in a DataFrame**
#    - Use **`df.at[row_index, col_label] = value`** to modify individual cells.
#    - **Avoid SettingWithCopyWarning** by working on a copy of the DataFrame:
#      ```python
#      df = df.copy()
#      ```
#
# 5. **📊 Expected DataFrame Format**
#     | **TeamName**        | **MatchesPlayed** | **MatchesWon** | **NoResult** | **Points** | **SeasonPosition** |
#     |----------------------|------------------|---------------|------------|----------|------------------|
#     | Gujarat Titans      | 16               | 12            | 0          | 24       | **Winner**       |
#     | Rajasthan Royals    | 17               | 10            | 0          | 20       | **Runner**       |
#     | Team XYZ           | 16               | 9             | 1          | 19       | **3**            |
#     | Team ABC           | 15               | 8             | 1          | 17       | **4**            |
#     | Team PQR           | 15               | 7             | 1          | 15       | **5**            |
#
# 6. **🚀 Final Output Example (Top 2 from 2022)**
#     ```plaintext
#     TeamName          MatchesPlayed  MatchesWon  NoResult  Points  SeasonPosition
#     Gujarat Titans          16         12         0       24       Winner
#     Rajasthan Royals        17         10         0       20       Runner
#     ...
#     ```
#
# 7. **📌 Notes:**
#    - The **function should return the complete table** with `"SeasonPosition"`.
#    - Ensure the `"SeasonPosition"` column is updated **correctly** based on match results.
#    - Use **`rank()`** for non-top-4 teams.
#
# 🚀 **Call Example:**
# ```python
# points_table('2022')
# ```

# %%
def get_loosing_team(df):
    if df.WinningTeam == df.Team1:
        return df.Team2
    else:
        return df.Team1

# %%
def point_table_extension(season : str):
    season_matches = ipl_df[ipl_df.Season == season].copy()
    table = point_table(season = season)

    table['SeasonPosition'] = table.Points.rank(
        method = 'first',
        ascending = False
    ).astype('object')

    winning_team = season_matches.WinningTeam[season_matches.MatchNumber == 'Final'].values[0]
    table.at[winning_team, 'SeasonPosition'] = 'Winner'

    season_matches['LosingTeam'] = season_matches.apply(func = get_loosing_team, axis=1)

    runner_team = season_matches.LosingTeam[season_matches.MatchNumber == 'Final'].values[0]
    table.at[runner_team, 'SeasonPosition'] = 'Runner'

    third_team = season_matches.LosingTeam[season_matches.MatchNumber == 'Qualifier 2'].values[0]
    table.at[third_team, 'SeasonPosition'] = 3

    fourth_team = season_matches.LosingTeam[season_matches.MatchNumber == 'Eliminator'].values[0]
    table.at[fourth_team, 'SeasonPosition'] = 4

    return table

# %%
point_table_extension('2022')
# Out:
#                              MatchesPlayed  MathcesWon  NoResult  Points  \
# TeamName
# Gujarat Titans                          16          12         0      24
# Rajasthan Royals                        17          10         0      20
# Lucknow Super Giants                    15           9         0      18
# Royal Challengers Bangalore             16           9         0      18
# Delhi Capitals                          14           7         0      14
# Punjab Kings                            14           7         0      14
# Kolkata Knight Riders                   14           6         0      12
# Sunrisers Hyderabad                     14           6         0      12
# Chennai Super Kings                     14           4         0       8
# Mumbai Indians                          14           4         0       8
#
#                             SeasonPosition
# TeamName
# Gujarat Titans                      Winner
# Rajasthan Royals                    Runner
# ...
