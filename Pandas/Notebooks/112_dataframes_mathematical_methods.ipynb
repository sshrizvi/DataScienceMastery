# %% [markdown]
# # **Article 112 : DataFrame Mathematical Methods** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Notebooks/112_dataframes_mathematical_methods.ipynb)
#
# |🔴 **NOTE** 🔴|
# |:-----------:|
# |This notebook contains the practical implementations of the concepts discussed in the following article.|
# | Here is Article 112 - [DataFrames Mathematical Methods](../Articles/112_dataframes_mathematical_methods.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ⚠️ **Data Warning**
# The data is in the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrames**

# %%
ipl_df = pd.read_csv('../Resources/Data/ipl-matches.csv')
ipl_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies_df = pd.read_csv('../Resources/Data/movies.csv')
movies_df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
dict_data = {
    'IQ' : [100, 120, 140, 160, 180],
    'MARKS' : [200, 220, 240, 260, 280],
    'PACKAGE' : [60, 70, 80, 90, 100]
}
students_df = pd.DataFrame(data = dict_data)
students_df
# Out:
#     IQ  MARKS  PACKAGE
# 0  100    200       60
# 1  120    220       70
# 2  140    240       80
# 3  160    260       90
# 4  180    280      100

# %% [markdown]
# ### 🚀 **DataFrame Mathematical Methods**

# %% [markdown]
# #### 🎯 ***1. DataFrame.sum()***

# %%
students_df.sum()
# Out:
# IQ          700
# MARKS      1200
# PACKAGE     400
# dtype: int64

# %%
students_df.sum(axis = 1)
# Out:
# 0    360
# 1    410
# 2    460
# 3    510
# 4    560
# dtype: int64

# %%
ipl_df.sum(numeric_only=True)
# Out:
# ID        788960985.0
# Margin        15897.0
# dtype: float64

# %%
movies_df.sum(numeric_only=True)
# Out:
# is_adult                 0.0
# year_of_release    3274720.0
# imdb_rating           9053.1
# imdb_votes         8770965.0
# dtype: float64

# %% [markdown]
# #### 🎯 ***2. DataFrame.product()***

# %%
ipl_df.product(numeric_only=True)
# Out:
# ID        0.0
# Margin    inf
# dtype: float64

# %%
movies_df.product(numeric_only=True)
# Out:
# is_adult           0.0
# year_of_release    0.0
# imdb_rating        0.0
# imdb_votes         0.0
# dtype: float64

# %%
students_df.product()
# Out:
# IQ          48384000000
# MARKS      768768000000
# PACKAGE      3024000000
# dtype: int64

# %%
students_df.product(axis=1)
# Out:
# 0    1200000
# 1    1848000
# 2    2688000
# 3    3744000
# 4    5040000
# dtype: int64

# %% [markdown]
# #### 🎯 ***3. DataFrame.mean()***

# %%
ipl_df.mean(numeric_only=True)
# Out:
# ID        830485.247368
# Margin        17.056867
# dtype: float64

# %%
movies_df.mean(numeric_only=True)
# Out:
# is_adult              0.000000
# year_of_release    2010.263966
# imdb_rating           5.557459
# imdb_votes         5384.263352
# dtype: float64

# %%
students_df.mean()
# Out:
# IQ         140.0
# MARKS      240.0
# PACKAGE     80.0
# dtype: float64

# %%
students_df.mean(axis=1)
# Out:
# 0    120.000000
# 1    136.666667
# 2    153.333333
# 3    170.000000
# 4    186.666667
# dtype: float64

# %% [markdown]
# #### 🎯 ***4. DataFrame.median()***

# %%
ipl_df.median(numeric_only=True)
# Out:
# ID        829738.0
# Margin         8.0
# dtype: float64

# %%
movies_df.median(numeric_only=True)
# Out:
# is_adult              0.0
# year_of_release    2011.0
# imdb_rating           5.6
# imdb_votes         1000.0
# dtype: float64

# %%
students_df.median()
# Out:
# IQ         140.0
# MARKS      240.0
# PACKAGE     80.0
# dtype: float64

# %%
students_df.median(axis=1)
# Out:
# 0    100.0
# 1    120.0
# 2    140.0
# 3    160.0
# 4    180.0
# dtype: float64

# %% [markdown]
# #### 🎯 ***5. DataFrame.mode()***

# %%
ipl_df.mode()
# Out:
#           ID    City        Date Season MatchNumber  \
# 0     335982  Mumbai  2008-04-19   2013           1
# 1     335983     NaN  2008-04-20    NaN          10
# 2     335984     NaN  2008-04-26    NaN          11
# 3     335985     NaN  2008-04-27    NaN          12
# 4     335986     NaN  2008-05-01    NaN          14
# ..       ...     ...         ...    ...         ...
# 945  1304116     NaN         NaN    NaN         NaN
# 946  1312197     NaN         NaN    NaN         NaN
# 947  1312198     NaN         NaN    NaN         NaN
# 948  1312199     NaN         NaN    NaN         NaN
# 949  1312200     NaN         NaN    NaN         NaN
#
#                            Team1           Team2         Venue  \
# 0    Royal Challengers Bangalore  Mumbai Indians  Eden Gardens
# 1                            NaN             NaN           NaN
# 2                            NaN             NaN           NaN
# 3                            NaN             NaN           NaN
# ...

# %%
movies_df.mode()
# Out:
#                       title_x    imdb_id  \
# 0                      Andaaz  tt0169102
# 1              Gabbar Is Back  tt0346507
# 2                      Lagaan  tt0347416
# 3     Tanu Weds Manu: Returns  tt1954470
# 4                         NaN  tt2140465
# ...                       ...        ...
# 1624                      NaN        NaN
# 1625                      NaN        NaN
# 1626                      NaN        NaN
# 1627                      NaN        NaN
# 1628                      NaN        NaN
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1624                                                NaN
# ...

# %%
students_df.mode()
# Out:
#     IQ  MARKS  PACKAGE
# 0  100    200       60
# 1  120    220       70
# 2  140    240       80
# 3  160    260       90
# 4  180    280      100

# %% [markdown]
# #### 🎯 ***6. DataFrame.std()***

# %%
ipl_df.std(numeric_only=True)
# Out:
# ID        337567.829494
# Margin        21.633109
# dtype: float64

# %%
movies_df.std(numeric_only=True)
# Out:
# is_adult               0.000000
# year_of_release        5.381542
# imdb_rating            1.567609
# imdb_votes         14552.103231
# dtype: float64

# %%
students_df.std()
# Out:
# IQ         31.622777
# MARKS      31.622777
# PACKAGE    15.811388
# dtype: float64

# %%
students_df.std(ddof=0)
# Out:
# IQ         28.284271
# MARKS      28.284271
# PACKAGE    14.142136
# dtype: float64

# %% [markdown]
# #### 🎯 ***7. DataFrame.var()***

# %%
ipl_df.var(numeric_only=True)
# Out:
# ID        1.139520e+11
# Margin    4.679914e+02
# dtype: float64

# %%
movies_df.var(numeric_only=True)
# Out:
# is_adult           0.000000e+00
# year_of_release    2.896099e+01
# imdb_rating        2.457397e+00
# imdb_votes         2.117637e+08
# dtype: float64

# %%
students_df.var()
# Out:
# IQ         1000.0
# MARKS      1000.0
# PACKAGE     250.0
# dtype: float64

# %%
students_df.var(axis=1)
# Out:
# 0    5200.000000
# 1    5833.333333
# 2    6533.333333
# 3    7300.000000
# 4    8133.333333
# dtype: float64
