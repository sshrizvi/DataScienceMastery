# %% [markdown]
# # **Article 113 : Selecting Rows and Columns** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Notebooks/113_selecting_rows_and_columns.ipynb)
#
# |🔴 **NOTE** 🔴|
# |:-----------:|
# |This notebook contains the practical implementations of the concepts discussed in the following article.|
# | Here is Article 113 - [Selecting Rows and Columns](../Articles/113_selecting_rows_and_columns.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ⚠️ **Data Warning**
# The data is in the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrames**

# %%
ipl_df = pd.read_csv('../Resources/Data/ipl-matches.csv')
ipl_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies_df = pd.read_csv('../Resources/Data/movies.csv')
movies_df
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
dict_data = {
    'NAME' : ['Shujaat', 'Abbas', 'Ali', 'Chandra', 'Verma'],
    'IQ' : [100, 120, 140, 160, 180],
    'MARKS' : [200, 220, 240, 260, 280],
    'PACKAGE' : [60, 70, 80, 90, 100]
}
students_df = pd.DataFrame(data = dict_data)
students_df.set_index('NAME', inplace=True)
students_df
# Out:
#           IQ  MARKS  PACKAGE
# NAME
# Shujaat  100    200       60
# Abbas    120    220       70
# Ali      140    240       80
# Chandra  160    260       90
# Verma    180    280      100

# %% [markdown]
# ### 🚀 **Selecting Columns**

# %% [markdown]
# #### 🎯 **1. Single Column**

# %%
ipl_df['ID']
# Out:
# 0      1312200
# 1      1312199
# 2      1312198
# 3      1312197
# 4      1304116
#         ...
# 945     335986
# 946     335985
# 947     335984
# 948     335983
# 949     335982
# Name: ID, Length: 950, dtype: int64

# %%
type(ipl_df['ID'])
# Out:
# pandas.core.series.Series

# %%
movies_df['actors']
# Out:
# 0       Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1       Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2       Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1629, dtype: object

# %%
type(movies_df['actors'])
# Out:
# pandas.core.series.Series

# %%
students_df['PACKAGE']
# Out:
# 0     60
# 1     70
# 2     80
# 3     90
# 4    100
# Name: PACKAGE, dtype: int64

# %% [markdown]
# #### 🎯 **2. Multiple Columns**

# %%
ipl_df[['ID', 'City', 'WinningTeam']]
# Out:
#           ID        City                  WinningTeam
# 0    1312200   Ahmedabad               Gujarat Titans
# 1    1312199   Ahmedabad             Rajasthan Royals
# 2    1312198     Kolkata  Royal Challengers Bangalore
# 3    1312197     Kolkata               Gujarat Titans
# 4    1304116      Mumbai                 Punjab Kings
# ..       ...         ...                          ...
# 945   335986     Kolkata        Kolkata Knight Riders
# 946   335985      Mumbai  Royal Challengers Bangalore
# 947   335984       Delhi             Delhi Daredevils
# 948   335983  Chandigarh          Chennai Super Kings
# 949   335982   Bangalore        Kolkata Knight Riders
#
# [950 rows x 3 columns]

# %%
movies_df[['title_x', 'original_title', 'release_date']]
# Out:
#                                    title_x                 original_title  \
# 0                 Uri: The Surgical Strike       Uri: The Surgical Strike
# 1                            Battalion 609                  Battalion 609
# 2     The Accidental Prime Minister (film)  The Accidental Prime Minister
# 3                          Why Cheat India                Why Cheat India
# 4                          Evening Shadows                Evening Shadows
# ...                                    ...                            ...
# 1624                 Tera Mera Saath Rahen          Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar           Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh                Sabse Bada Sukh
# 1627                                 Daaka                          Daaka
# 1628                              Humsafar                       Humsafar
#
#                   release_date
# 0        11 January 2019 (USA)
# ...

# %% [markdown]
# ### 🚀 **Selecting Rows**

# %% [markdown]
# #### 🎯 **1. Using `iloc[]`**

# %% [markdown]
# ##### **a. Single Row**

# %%
ipl_df.iloc[0]
# Out:
# ID                                                           1312200
# City                                                       Ahmedabad
# Date                                                      2022-05-29
# Season                                                          2022
# MatchNumber                                                    Final
# Team1                                               Rajasthan Royals
# Team2                                                 Gujarat Titans
# Venue                               Narendra Modi Stadium, Ahmedabad
# TossWinner                                          Rajasthan Royals
# TossDecision                                                     bat
# SuperOver                                                          N
# WinningTeam                                           Gujarat Titans
# WonBy                                                        Wickets
# Margin                                                           7.0
# ...

# %%
type(ipl_df.iloc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ##### **b. Multiple Rows using Slicing**

# %%
movies_df.iloc[0:10]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 5  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ##### **c. Multiple Rows using Fancy Indexing**

# %%
movies_df.iloc[[1, 5, 940]]
# Out:
#            title_x    imdb_id  \
# 1    Battalion 609  tt9472208
# 5      Soni (film)  tt6078866
# 940  Paying Guests  tt1176961
#
#                                            poster_path  \
# 1                                                  NaN
# 5    https://upload.wikimedia.org/wikipedia/en/thum...
# 940  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                        wiki_link        title_y  \
# 1    https://en.wikipedia.org/wiki/Battalion_609  Battalion 609
# 5      https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 940  https://en.wikipedia.org/wiki/Paying_Guests  Paying Guests
#
#     original_title  is_adult  year_of_release runtime        genres  \
# 1    Battalion 609         0             2019     131           War
# 5             Soni         0             2018      97         Drama
# 940  Paying Guests         0             2009     109  Comedy|Drama
#
#      imdb_rating  imdb_votes  \
# 1            4.1          73
# ...

# %% [markdown]
# ##### **d. Multiple Rows using Boolean Array**

# %%
mask = movies_df.index % 100 == 0
movies_df.iloc[mask]
# Out:
#                           title_x    imdb_id  \
# 0        Uri: The Surgical Strike  tt8291224
# 100           October (2018 film)  tt7700730
# 200   Tubelight (2017 Hindi film)  tt5882970
# 300                 7 Hours to Go  tt4365060
# 400         NH-8 Road to Nidhivan  tt4671212
# 500           Kahin Hai Mera Pyar  tt3585758
# 600              Aurangzeb (film)  tt2804026
# 700                  Ek Tha Tiger  tt2016894
# 800       Saheb Biwi Aur Gangster  tt2073070
# 900                         Mirch  tt1388903
# 1000              Woodstock Villa  tt1043876
# 1100         Marigold (2007 film)  tt0329354
# 1200            Shiva (2006 film)  tt0831816
# 1300                 Socha Na Tha  tt0451919
# 1400     Main Prem Ki Diwani Hoon  tt0265148
# 1500                  Agni Varsha  tt0326722
# 1600                       Kasoor  tt0272688
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# #### 🎯 **2. Using `loc[]`**

# %% [markdown]
# ##### **a. Single Row**

# %%
students_df.loc['Shujaat']
# Out:
# IQ         100
# MARKS      200
# PACKAGE     60
# Name: Shujaat, dtype: int64

# %% [markdown]
# ##### **b. Multiple Rows using Fancy Indexing**

# %%
students_df.loc[['Shujaat', 'Ali', 'Verma']]
# Out:
#           IQ  MARKS  PACKAGE
# NAME
# Shujaat  100    200       60
# Ali      140    240       80
# Verma    180    280      100

# %% [markdown]
# ##### **c. Multiple Rows using Slicing**

# %%
students_df.loc['Ali':'Chandra']
# Out:
#           IQ  MARKS  PACKAGE
# NAME
# Ali      140    240       80
# Chandra  160    260       90

# %%
students_df.loc['Shujaat':'Verma':2]
# Out:
#           IQ  MARKS  PACKAGE
# NAME
# Shujaat  100    200       60
# Ali      140    240       80
# Verma    180    280      100

# %% [markdown]
# ##### **d. Multiple Rows using Boolean Array**

# %%
mask = students_df.index == 'Ali'
students_df.loc[mask]
# Out:
#        IQ  MARKS  PACKAGE
# NAME
# Ali   140    240       80

# %% [markdown]
# ##### **e. Multiple Rows using Callable Function**

# %%
students_df.loc[lambda x : x['PACKAGE'] > x['PACKAGE'].mean()]
# Out:
#           IQ  MARKS  PACKAGE
# NAME
# Chandra  160    260       90
# Verma    180    280      100

# %% [markdown]
# ### 🚀 **Selecting Both Rows and Columns**

# %% [markdown]
# #### 🎯 **1. Using `iloc[row, column]`**

# %%
ipl_df.iloc[0:5, 0:3]
# Out:
#         ID       City        Date
# 0  1312200  Ahmedabad  2022-05-29
# 1  1312199  Ahmedabad  2022-05-27
# 2  1312198    Kolkata  2022-05-25
# 3  1312197    Kolkata  2022-05-24
# 4  1304116     Mumbai  2022-05-22

# %% [markdown]
# #### 🎯 **2. Using `loc[row, column]`**

# %%
students_df.loc['Shujaat':'Ali', 'PACKAGE']
# Out:
# NAME
# Shujaat    60
# Abbas      70
# Ali        80
# Name: PACKAGE, dtype: int64
