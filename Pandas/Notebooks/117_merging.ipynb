# %% [markdown]
# # **Article 117 : Merging, Joining & Concatenating** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Notebooks/117_merging.ipynb)
#
# |🔴 **NOTE** 🔴|
# |:-----------:|
# |This notebook contains the practical implementations of the concepts discussed in the following article.|
# | Here is Article 117 - [Merging, Joining & Concatenating](../Articles/117_merging.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ⚠️ **Data Warning**
# The data is in the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrames**

# %%
courses = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/courses.csv'
)
courses
# Out:
#     course_id       course_name  price
# 0           1            python   2499
# 1           2               sql   3499
# 2           3     data analysis   4999
# 3           4  machine learning   9999
# 4           5           tableau   2499
# 5           6          power bi   1899
# 6           7          ms sxcel   1599
# 7           8            pandas   1099
# 8           9            plotly    699
# 9          10           pyspark   2499
# 10         11             Numpy    699
# 11         12               C++   1299

# %%
students = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/students.csv'
)
students
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 1            2         Esha Butala        1
# 2            3      Parveen Bhalla        3
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 6            7        Tarun Thaker        9
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 10          11  David Mukhopadhyay       20
# 11          12          Radha Dutt       19
# 12          13      Munni Varghese       24
# 13          14    Pranab Natarajan       22
# 14          15           Preet Sha       16
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 18          19        Qabeel Raman       12
# 19          20       Hanuman Hegde       11
# ...

# %%
november = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/reg-month1.csv'
)
november
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3

# %%
december = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/reg-month2.csv'
)
december
# Out:
#     student_id  course_id
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# 9           11          8
# 10          14          6
# 11          12          5
# 12          12          7
# 13          18          8
# 14           1         10
# 15           1          9
# 16           2          5
# 17           7          6
# 18          22          5
# 19          22          6
# 20          23          9
# 21          23          5
# 22          14          4
# 23          14          1
# 24          11         10
# 25          42          9
# 26          50          8
# 27          38          1

# %%
matches = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/matches.csv'
)
matches
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
deliveries = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/deliveries.csv'
)
deliveries
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# ### 🚀 **Concatenating Two DataFrames : pd.concat()**

# %% [markdown]
# #### 📦 **Concatenating Two DataFrames Vertically `axis = 0`**

# %%
pd.concat(
    objs = [
        november,
        december
    ]
)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 0            3          5
# 1           16          7
# 2           12         10
# 3           12          1
# 4           14          9
# 5            7          7
# 6            7          2
# 7           16          3
# 8           17         10
# ...

# %%
pd.concat(
    objs = [
        november,
        december
    ],
    ignore_index = True
)
# Out:
#     student_id  course_id
# 0           23          1
# 1           15          5
# 2           18          6
# 3           23          4
# 4           16          9
# 5           18          1
# 6            1          1
# 7            7          8
# 8           22          3
# 9           15          1
# 10          19          4
# 11           1          6
# 12           7         10
# 13          11          7
# 14          13          3
# 15          24          4
# 16          21          1
# 17          16          5
# 18          23          3
# 19          17          7
# 20          23          6
# 21          25          1
# 22          19          2
# 23          25         10
# 24           3          3
# 25           3          5
# 26          16          7
# 27          12         10
# 28          12          1
# 29          14          9
# 30           7          7
# 31           7          2
# 32          16          3
# 33          17         10
# ...

# %%
pd.concat(
    objs = [
        november,
        december
    ],
    keys = [
        'November',
        'December'
    ]
)
# Out:
#              student_id  course_id
# November 0           23          1
#          1           15          5
#          2           18          6
#          3           23          4
#          4           16          9
#          5           18          1
#          6            1          1
#          7            7          8
#          8           22          3
#          9           15          1
#          10          19          4
#          11           1          6
#          12           7         10
#          13          11          7
#          14          13          3
#          15          24          4
#          16          21          1
#          17          16          5
#          18          23          3
#          19          17          7
#          20          23          6
#          21          25          1
#          22          19          2
#          23          25         10
#          24           3          3
# December 0            3          5
# ...

# %%
pd.concat(
    objs = [
        november,
        december
    ],
    keys = [
        'November',
        'December'
    ],
    names = [
        'Month',
        'Number'
    ]
)
# Out:
#                  student_id  course_id
# Month    Number
# November 0               23          1
#          1               15          5
#          2               18          6
#          3               23          4
#          4               16          9
#          5               18          1
#          6                1          1
#          7                7          8
#          8               22          3
#          9               15          1
#          10              19          4
#          11               1          6
#          12               7         10
#          13              11          7
#          14              13          3
#          15              24          4
#          16              21          1
#          17              16          5
#          18              23          3
#          19              17          7
#          20              23          6
#          21              25          1
# ...

# %% [markdown]
# #### 📦 **Concatenating Two DataFrames Horizontally `axis = 1`**

# %%
pd.concat(
    objs = [
        november,
        december
    ],
    axis = 1
)
# Out:
#     student_id  course_id  student_id  course_id
# 0         23.0        1.0           3          5
# 1         15.0        5.0          16          7
# 2         18.0        6.0          12         10
# 3         23.0        4.0          12          1
# 4         16.0        9.0          14          9
# 5         18.0        1.0           7          7
# 6          1.0        1.0           7          2
# 7          7.0        8.0          16          3
# 8         22.0        3.0          17         10
# 9         15.0        1.0          11          8
# 10        19.0        4.0          14          6
# 11         1.0        6.0          12          5
# 12         7.0       10.0          12          7
# 13        11.0        7.0          18          8
# 14        13.0        3.0           1         10
# 15        24.0        4.0           1          9
# 16        21.0        1.0           2          5
# 17        16.0        5.0           7          6
# ...

# %%
pd.concat(
    objs = [
        november,
        december
    ],
    keys = [
        'November',
        'December'
    ],
    axis = 1
)
# Out:
#      November             December
#    student_id course_id student_id course_id
# 0        23.0       1.0          3         5
# 1        15.0       5.0         16         7
# 2        18.0       6.0         12        10
# 3        23.0       4.0         12         1
# 4        16.0       9.0         14         9
# 5        18.0       1.0          7         7
# 6         1.0       1.0          7         2
# 7         7.0       8.0         16         3
# 8        22.0       3.0         17        10
# 9        15.0       1.0         11         8
# 10       19.0       4.0         14         6
# 11        1.0       6.0         12         5
# 12        7.0      10.0         12         7
# 13       11.0       7.0         18         8
# 14       13.0       3.0          1        10
# 15       24.0       4.0          1         9
# 16       21.0       1.0          2         5
# 17       16.0       5.0          7         6
# 18       23.0       3.0         22         5
# ...

# %% [markdown]
# ### 🚀 **Joins**

# %% [markdown]
# #### 📦 **Inner Join**

# %%
pd.merge(
    right = november,
    left = students,
    how = 'inner',
    on = 'student_id'
)
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23          1
# 1            1       Kailash Harjo       23          6
# 2            3      Parveen Bhalla        3          3
# 3            7        Tarun Thaker        9          8
# 4            7        Tarun Thaker        9         10
# 5           11  David Mukhopadhyay       20          7
# 6           13      Munni Varghese       24          3
# 7           15           Preet Sha       16          5
# 8           15           Preet Sha       16          1
# 9           16        Elias Dodiya       25          9
# 10          16        Elias Dodiya       25          5
# 11          17        Yasmin Palan        7          7
# 12          18     Fardeen Mahabir       13          6
# 13          18     Fardeen Mahabir       13          1
# 14          19        Qabeel Raman       12          4
# 15          19        Qabeel Raman       12          2
# ...

# %% [markdown]
# #### 📦 **Left Join**

# %%
pd.merge(
    left = students,
    right = november,
    how = 'left',
    on = 'student_id'
)
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23        1.0
# 1            1       Kailash Harjo       23        6.0
# 2            2         Esha Butala        1        NaN
# 3            3      Parveen Bhalla        3        3.0
# 4            4         Marlo Dugal       14        NaN
# 5            5         Kusum Bahri        6        NaN
# 6            6  Lakshmi Contractor       10        NaN
# 7            7        Tarun Thaker        9        8.0
# 8            7        Tarun Thaker        9       10.0
# 9            8      Radheshyam Dey        5        NaN
# 10           9   Nitika Chatterjee        4        NaN
# 11          10      Aayushman Sant        8        NaN
# 12          11  David Mukhopadhyay       20        7.0
# 13          12          Radha Dutt       19        NaN
# 14          13      Munni Varghese       24        3.0
# 15          14    Pranab Natarajan       22        NaN
# ...

# %% [markdown]
# #### 📦 **Right Join**

# %%
pd.merge(
    left = students,
    right = november,
    how = 'right',
    on = 'student_id'
)
# Out:
#     student_id                name  partner  course_id
# 0           23      Chhavi Lachman       18          1
# 1           15           Preet Sha       16          5
# 2           18     Fardeen Mahabir       13          6
# 3           23      Chhavi Lachman       18          4
# 4           16        Elias Dodiya       25          9
# 5           18     Fardeen Mahabir       13          1
# 6            1       Kailash Harjo       23          1
# 7            7        Tarun Thaker        9          8
# 8           22          Yash Sethi       21          3
# 9           15           Preet Sha       16          1
# 10          19        Qabeel Raman       12          4
# 11           1       Kailash Harjo       23          6
# 12           7        Tarun Thaker        9         10
# 13          11  David Mukhopadhyay       20          7
# 14          13      Munni Varghese       24          3
# 15          24        Radhika Suri       17          4
# ...

# %% [markdown]
# #### 📦 **Outer Join**

# %%
pd.merge(
    left = students,
    right = november,
    how = 'outer',
    on = 'student_id'
)
# Out:
#     student_id                name  partner  course_id
# 0            1       Kailash Harjo       23        1.0
# 1            1       Kailash Harjo       23        6.0
# 2            2         Esha Butala        1        NaN
# 3            3      Parveen Bhalla        3        3.0
# 4            4         Marlo Dugal       14        NaN
# 5            5         Kusum Bahri        6        NaN
# 6            6  Lakshmi Contractor       10        NaN
# 7            7        Tarun Thaker        9        8.0
# 8            7        Tarun Thaker        9       10.0
# 9            8      Radheshyam Dey        5        NaN
# 10           9   Nitika Chatterjee        4        NaN
# 11          10      Aayushman Sant        8        NaN
# 12          11  David Mukhopadhyay       20        7.0
# 13          12          Radha Dutt       19        NaN
# 14          13      Munni Varghese       24        3.0
# 15          14    Pranab Natarajan       22        NaN
# ...

# %% [markdown]
# ### 🚀 **Questions on Joins**

# %% [markdown]
# #### 🎯 **Q1. Find the total revenue generated.**

# %%
total_registrations = pd.concat(
    objs = [
        november,
        december
    ],
    axis = 0,
    ignore_index = True
)

total_revenue = pd.merge(
    left = total_registrations,
    right = courses,
    how = 'inner', 
    on = 'course_id'
)['price'].sum()

print(
    'Total Revenue Generated : {}'.format(
        total_revenue
    )
)
# Out:
# Total Revenue Generated : 154247

# %% [markdown]
# #### 🎯 **Q2. Find Month by Month Revenue.**

# %%
total_registrations = pd.concat(
    objs = [
        november,
        december
    ],
    axis = 0,
    keys = [
        'November',
        'December'
    ]
)

for i in total_registrations.index.levels[0]:
    month_revenue = pd.merge(
        left = total_registrations.loc[i],
        right = courses,
        how = 'inner',
        on = 'course_id'
    )['price'].sum()
    print(
        'Revenue for Month {} is Rs. {}'.format(
            i, month_revenue
        )
    )
# Out:
# Revenue for Month November is Rs. 89175
# Revenue for Month December is Rs. 65072

# %% [markdown]
# #### 🎯 **Q3. Print the Registration Table (Name, Course, Price)**

# %%
total_registrations = pd.concat(
    objs = [
        november,
        december
    ],
    axis = 0,
    ignore_index = True
)

pd.merge(
    left = total_registrations,
    right = students,
    how = 'inner',
    on = 'student_id'
).merge(
    right = courses,
    how = 'inner',
    on = 'course_id'
)[
    ['name', 'course_name', 'price']
]
# Out:
#                   name       course_name  price
# 0       Chhavi Lachman            python   2499
# 1            Preet Sha           tableau   2499
# 2      Fardeen Mahabir          power bi   1899
# 3       Chhavi Lachman  machine learning   9999
# 4         Elias Dodiya            plotly    699
# 5      Fardeen Mahabir            python   2499
# 6        Kailash Harjo            python   2499
# 7         Tarun Thaker            pandas   1099
# 8           Yash Sethi     data analysis   4999
# 9            Preet Sha            python   2499
# 10        Qabeel Raman  machine learning   9999
# 11       Kailash Harjo          power bi   1899
# 12        Tarun Thaker           pyspark   2499
# 13  David Mukhopadhyay          ms sxcel   1599
# 14      Munni Varghese     data analysis   4999
# 15        Radhika Suri  machine learning   9999
# 16          Seema Kota            python   2499
# 17        Elias Dodiya           tableau   2499
# 18      Chhavi Lachman     data analysis   4999
# ...

# %% [markdown]
# #### 🎯 **Q4. Plot bar chart of revenue for each course.**

# %%
total_registrations = pd.concat(
    objs = [
        november,
        december
    ],
    axis = 0,
    ignore_index = True
)

pd.merge(
    left = total_registrations,
    right = courses,
    how = 'inner',
    on = 'course_id'
)[['course_name', 'price']].groupby(
    by = 'course_name'
).sum().plot(
    kind = 'bar'
)
# Out:
# <Axes: xlabel='course_name'>

# %% [markdown]
# #### 🎯 **Q5. Find the students who enrolled in both November and December.**

# %%
nov_unique = november['student_id'].unique()
dec_unique = december['student_id'].unique()

mask = students['student_id'].isin(
    np.intersect1d(
        ar1 = nov_unique,
        ar2 = dec_unique
    )
)
students[mask]
# Out:
#     student_id                name  partner
# 0            1       Kailash Harjo       23
# 2            3      Parveen Bhalla        3
# 6            7        Tarun Thaker        9
# 10          11  David Mukhopadhyay       20
# 15          16        Elias Dodiya       25
# 16          17        Yasmin Palan        7
# 17          18     Fardeen Mahabir       13
# 21          22          Yash Sethi       21
# 22          23      Chhavi Lachman       18

# %% [markdown]
# #### 🎯 **Q6. Find course that got NO enrollment.**

# %%
nov_unique = november['course_id'].unique()
dec_unique = december['course_id'].unique()

mask = ~courses['course_id'].isin(
    np.union1d(
        ar1 = nov_unique,
        ar2 = dec_unique
    )
)
courses[mask]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %%
courses[
    courses['course_id'].isin(
        np.setdiff1d(
            ar1 = courses['course_id'],
            ar2 = total_registrations['course_id']
        )
    )
]
# Out:
#     course_id course_name  price
# 10         11       Numpy    699
# 11         12         C++   1299

# %% [markdown]
# #### 🎯 **Q7. Find students who did not enroll into any courses.**

# %%
students[
    students['student_id'].isin(
        np.setdiff1d(
            ar1 = students['student_id'],
            ar2 = total_registrations['student_id']
        )
    )
]
# Out:
#     student_id                name  partner
# 3            4         Marlo Dugal       14
# 4            5         Kusum Bahri        6
# 5            6  Lakshmi Contractor       10
# 7            8      Radheshyam Dey        5
# 8            9   Nitika Chatterjee        4
# 9           10      Aayushman Sant        8
# 19          20       Hanuman Hegde       11

# %% [markdown]
# #### 🎯 **Q8. Print Student Name - Partner Name for all enrolled students.**

# %%
pd.merge(
    left = students,
    right = students,
    left_on = 'partner',
    right_on = 'student_id'
)[
    ['name_x', 'name_y']
].rename(
    columns = {
        'name_x' : 'Student',
        'name_y' : 'Partner'
    }
)
# Out:
#                Student             Partner
# 0        Kailash Harjo      Chhavi Lachman
# 1          Esha Butala       Kailash Harjo
# 2       Parveen Bhalla      Parveen Bhalla
# 3          Marlo Dugal    Pranab Natarajan
# 4          Kusum Bahri  Lakshmi Contractor
# 5   Lakshmi Contractor      Aayushman Sant
# 6         Tarun Thaker   Nitika Chatterjee
# 7       Radheshyam Dey         Kusum Bahri
# 8    Nitika Chatterjee         Marlo Dugal
# 9       Aayushman Sant      Radheshyam Dey
# 10  David Mukhopadhyay       Hanuman Hegde
# 11          Radha Dutt        Qabeel Raman
# 12      Munni Varghese        Radhika Suri
# 13    Pranab Natarajan          Yash Sethi
# 14           Preet Sha        Elias Dodiya
# 15        Elias Dodiya     Shashank D’Alia
# 16        Yasmin Palan        Tarun Thaker
# 17     Fardeen Mahabir      Munni Varghese
# 18        Qabeel Raman          Radha Dutt
# 19       Hanuman Hegde  David Mukhopadhyay
# 20          Seema Kota           Preet Sha
# ...

# %% [markdown]
# #### 🎯 **Q9. Find the TOP 3 students who did most enrollments.**

# %%
top_3 = total_registrations['student_id'].value_counts().head(3)

students[
    students['student_id'].isin(
        values = top_3.index
    )
]
# Out:
#     student_id            name  partner
# 0            1   Kailash Harjo       23
# 6            7    Tarun Thaker        9
# 22          23  Chhavi Lachman       18

# %% [markdown]
# #### 🎯 **Q10. Find the TOP 3 students who spent most money.**

# %%
top3_spent = pd.merge(
    left = total_registrations,
    right = courses,
    how = 'inner',
    on = 'course_id'
).groupby(
    by = 'student_id'
)['price'].sum().sort_values(
    ascending = False
).head(3).index

students[
    students['student_id'].isin(
        values = top3_spent
    )
]
# Out:
#     student_id              name  partner
# 13          14  Pranab Natarajan       22
# 18          19      Qabeel Raman       12
# 22          23    Chhavi Lachman       18

# %% [markdown]
# ### 🚀 **Questions on IPL DataSet**

# %% [markdown]
# #### 🎯 **Q1. Find the TOP 3 Stadiums with highest SIXES/MATCHES ratio.**

# %%
def sixes_matches_ratio(group):
    match_count = group['id'].count()
    sixes_count = group['sixes_count'].sum()
    return (sixes_count/match_count)

# %%
match_run_count = deliveries.groupby(
    by = 'match_id'
)['batsman_runs'].value_counts().reset_index().rename(
    columns = {
        'count' : 'sixes_count'
    }
)

sixes = match_run_count[
    match_run_count['batsman_runs'] == 6
]

venue_group = pd.merge(
    left = matches,
    right = sixes,
    left_on = 'id',
    right_on = 'match_id'
).groupby(
    by = 'venue'
)

venue_group.apply(
    func = sixes_matches_ratio,
    include_groups = False
).sort_values(
    ascending = False
).head(3)
# Out:
# venue
# Holkar Cricket Stadium     17.600000
# M Chinnaswamy Stadium      13.227273
# Sharjah Cricket Stadium    12.666667
# dtype: float64

# %% [markdown]
# #### 🎯 **Q2. Find ORANGE CAP holder for all the seasons.**

# %%
def orange_cap(group):
    return group.sort_values(
        by = 'batsman_runs',
        ascending = False
    ).head(1)

# %%
temp_df = pd.merge(
    left = matches,
    right = deliveries,
    left_on = 'id',
    right_on = 'match_id'
)

temp_group = temp_df.groupby(
    by = [
        'season',
        'batsman'
    ]
)

total_runs = temp_group['batsman_runs'].sum().reset_index()

total_runs.groupby(
    by = 'season'
).apply(
    func = orange_cap,
    include_groups = False
)
# Out:
#                   batsman  batsman_runs
# season
# 2008   115       SE Marsh           616
# 2009   229      ML Hayden           572
# 2010   446   SR Tendulkar           618
# 2011   502       CH Gayle           608
# 2012   684       CH Gayle           733
# 2013   910     MEK Hussey           733
# 2014   1088    RV Uthappa           660
# 2015   1148     DA Warner           562
# 2016   1383       V Kohli           973
# 2017   1422     DA Warner           641
