# %% [markdown]
# # **Article 115 : Important DataFrame Methods** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Notebooks/115_important_dataframe_methods.ipynb)
#
# |🔴 **NOTE** 🔴|
# |:-----------:|
# |This notebook contains the practical implementations of the concepts discussed in the following article.|
# | Here is Article 115 - [Important DataFrame Methods](../Articles/115_important_dataframe_methods.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### ⚠️ **Data Warning**
# The data is in the [Resources](../Resources/) folder.

# %% [markdown]
# #### **Reading Data into DataFrames**

# %%
ipl_df = pd.read_csv('../Resources/Data/ipl-matches.csv')
ipl_df
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
movies = pd.read_csv('../Resources/Data/movies.csv')
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
dict_data = {
    'IQ' : [100, 120, 140, 160, 180, 180],
    'MARKS' : [200, 220, 240, 260, 280, 280],
    'PACKAGE' : [60, 70, 80, 90, 100, 100]
}
students_df = pd.DataFrame(data = dict_data)
students_df
# Out:
#     IQ  MARKS  PACKAGE
# 0  100    200       60
# 1  120    220       70
# 2  140    240       80
# 3  160    260       90
# 4  180    280      100
# 5  180    280      100

# %%
np.random.seed(42)
points = pd.DataFrame(
    data={
        'Point1':[(np.random.randint(0, 100), np.random.randint(0, 100)) for _ in range(15)],
        'Point2':[(np.random.randint(0, 100), np.random.randint(0, 100)) for _ in range(15)]
    }
)
points
# Out:
#       Point1    Point2
# 0   (51, 92)  (90, 58)
# 1   (14, 71)  (41, 91)
# 2   (60, 20)  (59, 79)
# 3   (82, 86)  (14, 61)
# 4   (74, 74)  (61, 46)
# 5   (87, 99)  (61, 50)
# 6    (23, 2)  (54, 63)
# 7   (21, 52)   (2, 50)
# 8    (1, 87)   (6, 20)
# 9   (29, 37)  (72, 38)
# 10   (1, 63)   (17, 3)
# 11  (59, 20)  (88, 59)
# 12  (32, 75)   (13, 8)
# 13  (57, 21)  (89, 52)
# 14  (88, 48)   (1, 83)

# %% [markdown]
# ### 🚀 **Important DataFrame Methods**
# **Note :** This article contains important dataframe methods definition, documentation link and example.

# %% [markdown]
# #### 📦 **1. DataFrame.value_counts()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.value_counts.html#pandas-dataframe-value-counts)
#
# **Description :** Return a Series containing the frequency of *each distinct row* in the Dataframe.
#
# **Note :** This method is not as much useful in DataFrame than in Series.

# %%
students_df.value_counts()
# Out:
# IQ   MARKS  PACKAGE
# 100  200    60         1
# 120  220    70         1
# 140  240    80         1
# 160  260    90         1
# 180  280    100        1
# Name: count, dtype: int64

# %% [markdown]
# ##### 🎯 **Q1. Find which player has won most player of the match in finals and qualifers.**

# %%
match_type_mask = ~(ipl_df['MatchNumber'].str.isdigit())
special_matches = ipl_df[match_type_mask]
special_matches['Player_of_Match'].value_counts(ascending=False)[0:3]
# Out:
# Player_of_Match
# KA Pollard      3
# F du Plessis    3
# SK Raina        3
# Name: count, dtype: int64

# %% [markdown]
# ##### 🎯 **Q2. Toss Decision Plot**
# Plot a pie chart showing the proportion of choice made by the captain on winning toss.

# %%
ipl_df['TossDecision'].value_counts().plot(kind='pie', title='Toss Decision Pie Chart')
# Out:
# <Axes: title={'center': 'Toss Decision Pie Chart'}, ylabel='count'>

# %% [markdown]
# ##### 🎯 **Q3. How many matches each team has played ?**

# %%
ipl_df['Team1'].value_counts() + ipl_df['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %% [markdown]
# #### 📦 **2. DataFrame.sort_values()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html#pandas-dataframe-sort-values)
#
# **Description :** Sort by the values along either axis.
#
# **Note :** The parameters of this method are very useful to perform sorting on values on the basis of multiple columns which enables a programmer to perform advanced sorting.

# %%
movies.sort_values('title_x')
# Out:
#                        title_x    imdb_id  \
# 1498        16 December (film)  tt0313844
# 1021               1920 (film)  tt1301698
# 287               1920: London  tt5638500
# 723     1920: The Evil Returns  tt2222550
# 1039          1971 (2007 film)  tt0983990
# ...                        ...        ...
# 778   Zindagi Na Milegi Dobara  tt1562872
# 670          Zindagi Tere Naam  tt2164702
# 756                   Zokkomon  tt1605790
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 1623                  Zubeidaa  tt0255713
#
#                                             poster_path  \
# 1498  https://upload.wikimedia.org/wikipedia/en/thum...
# 1021  https://upload.wikimedia.org/wikipedia/en/thum...
# 287   https://upload.wikimedia.org/wikipedia/en/thum...
# 723   https://upload.wikimedia.org/wikipedia/en/e/e7...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ##### 🎯 **Q1. Sort the movies dataset based on year of release (ascending) and then by title (ascending) ?**

# %%
movies.sort_values(by = ['year_of_release', 'title_x'])
# Out:
#                                title_x     imdb_id  \
# 1575                       Aalavandhan   tt0294264
# 1576  Aamdani Atthanni Kharcha Rupaiya   tt0305173
# 1577                Aashiq (2001 film)   tt0273406
# 1579               Ajnabee (2001 film)   tt0278291
# 1578                   Aks (2001 film)   tt0289845
# ...                                ...         ...
# 64                         Ujda Chaman  tt11046300
# 0             Uri: The Surgical Strike   tt8291224
# 3                      Why Cheat India   tt8108208
# 60                  Yaaram (2019 film)  tt11007050
# 73                  Yeh Saali Aashiqui  tt10443846
#
#                                             poster_path  \
# 1575  https://upload.wikimedia.org/wikipedia/en/thum...
# 1576  https://upload.wikimedia.org/wikipedia/en/thum...
# 1577  https://upload.wikimedia.org/wikipedia/en/c/c6...
# 1579  https://upload.wikimedia.org/wikipedia/en/thum...
# 1578  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ##### 🎯 **Q2. Sort the movies dataset based on year of release (ascending) and then by title (descending) ?**

# %%
movies.sort_values(by = ['year_of_release', 'title_x'], ascending = [True, False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# ##### 🎯 **Q3. Sort the given DataFrame on IQ in any order such that the NaN values of IQ appear on the top.**
#
# ```python
# dict_data = {
#     'IQ' : [100, 120, 140, np.nan, 160, np.nan, np.nan, 180],
#     'MARKS' : [np.nan, np.nan, 200, 220, 240, 260, 280, np.nan],
#     'PACKAGE' : [60, 70, 80, np.nan, 90, 100, np.nan, np.nan]
# }
# students = pd.DataFrame(data = dict_data)
# students
# ```

# %%
dict_data = {
    'IQ' : [100, 120, 140, np.nan, 160, np.nan, np.nan, 180, 200],
    'MARKS' : [np.nan, np.nan, 200, np.nan, 220, 240, 260, 280, np.nan],
    'PACKAGE' : [60, 70, 80, np.nan, 90, 100, np.nan, np.nan, 120]
}
students = pd.DataFrame(data = dict_data)
students
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 3    NaN    NaN      NaN
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %%
students.sort_values(by = 'IQ',
                     na_position = 'first')
# Out:
#       IQ  MARKS  PACKAGE
# 3    NaN  220.0      NaN
# 5    NaN  260.0    100.0
# 6    NaN  280.0      NaN
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 4  160.0  240.0     90.0
# 7  180.0    NaN      NaN

# %%
students.sort_values(by = 'IQ',
                     na_position = 'first',
                     ascending = False)
# Out:
#       IQ  MARKS  PACKAGE
# 3    NaN  220.0      NaN
# 5    NaN  260.0    100.0
# 6    NaN  280.0      NaN
# 7  180.0    NaN      NaN
# 4  160.0  240.0     90.0
# 2  140.0  200.0     80.0
# 1  120.0    NaN     70.0
# 0  100.0    NaN     60.0

# %% [markdown]
# #### 📦 **3. DataFrame.rank()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rank.html#pandas-dataframe-rank)
#
# **Description :** Compute numerical data ranks (1 through n) along axis. By default, equal values are assigned a rank that is the average of the ranks of those values.
#
# **Note :** The `rank()` method is not as much useful in DataFrames as in Series.

# %% [markdown]
# ##### 🎯 **Q1. Add a `batter_rank` column to `batsman_runs_ipl.csv`.**
#
# ```python
# batter = pd.read_csv('../Resources/Data/batsman_runs_ipl.csv')
# batter
# ```

# %%
batter = pd.read_csv('../Resources/Data/batsman_runs_ipl.csv')
batter
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batter['batter_rank'] = batter['batsman_run'].rank(ascending=False)

# %%
batter.sort_values('batter_rank')
# Out:
#            batter  batsman_run  batter_rank
# 569       V Kohli         6634          1.0
# 462      S Dhawan         6244          2.0
# 130     DA Warner         5883          3.0
# 430     RG Sharma         5881          4.0
# 493      SK Raina         5536          5.0
# ..            ...          ...          ...
# 512   SS Cottrell            0        594.0
# 466     S Kaushik            0        594.0
# 203     IC Pandey            0        594.0
# 467       S Ladda            0        594.0
# 468  S Lamichhane            0        594.0
#
# [605 rows x 3 columns]

# %% [markdown]
# #### 📦 **4. DataFrame.sort_index()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_index.html#pandas-dataframe-sort-index)
#
# **Description :** Sort object by labels (along an axis). Returns a new DataFrame sorted by label if inplace argument is False, otherwise updates the original DataFrame and returns None.

# %%
movies.sort_index(ascending=False)
# Out:
#                                    title_x     imdb_id  \
# 1628                              Humsafar   tt2403201
# 1627                                 Daaka  tt10833860
# 1626                       Sabse Bada Sukh   tt0069204
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1624                 Tera Mera Saath Rahen   tt0301250
# ...                                    ...         ...
# 4                          Evening Shadows   tt6028796
# 3                          Why Cheat India   tt8108208
# 2     The Accidental Prime Minister (film)   tt6986710
# 1                            Battalion 609   tt9472208
# 0                 Uri: The Surgical Strike   tt8291224
#
#                                             poster_path  \
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
movies.sort_index(axis='columns')
# Out:
#                                                  actors            genres  \
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...  Action|Drama|War
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...               War
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...   Biography|Drama
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...       Crime|Drama
# 4     Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...             Drama
# ...                                                 ...               ...
# 1624  Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...             Drama
# 1625  Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...             Drama
# 1626  Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...      Comedy|Drama
# 1627                          Gippy Grewal|Zareen Khan|            Action
# 1628                                        Fawad Khan|     Drama|Romance
#
#          imdb_id  imdb_rating  imdb_votes  is_adult  \
# ...

# %%
ipl_df.sort_index(ascending=False)
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 949   335982   Bangalore  2008-04-18  2007/08            1
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 947   335984       Delhi  2008-04-19  2007/08            3
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 945   335986     Kolkata  2008-04-20  2007/08            4
# ..       ...         ...         ...      ...          ...
# 4    1304116      Mumbai  2022-05-22     2022           70
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
#
#                            Team1                        Team2  \
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
# 948              Kings XI Punjab          Chennai Super Kings
# 947             Delhi Daredevils             Rajasthan Royals
# ...

# %% [markdown]
# #### 📦 **5. DataFrame.set_index()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.set_index.html#pandas-dataframe-set-index)
#
# **Description :** Set the DataFrame index using existing columns. Set the DataFrame index (row labels) using one or more existing columns or arrays (of the correct length). The index can replace the existing index or expand on it.
#
# **Note :** When you use `set_index()` method to set the index using existing column, by default, it removes previous index from it and set the new index. The problem can be solved by `reset_index()` method.

# %%
batter.set_index('batter')
# Out:
#                 batsman_run  batter_rank
# batter
# A Ashish Reddy          280        166.5
# A Badoni                161        226.0
# A Chandila                4        535.0
# A Chopra                 53        329.0
# A Choudhary              25        402.5
# ...                     ...          ...
# Yash Dayal                0        594.0
# Yashpal Singh            47        343.0
# Younis Khan               3        547.5
# Yuvraj Singh           2754         27.0
# Z Khan                  117        256.0
#
# [605 rows x 2 columns]

# %%
batter.set_index('batter',
                 inplace=True)
batter
# Out:
#                 batsman_run  batter_rank
# batter
# A Ashish Reddy          280        166.5
# A Badoni                161        226.0
# A Chandila                4        535.0
# A Chopra                 53        329.0
# A Choudhary              25        402.5
# ...                     ...          ...
# Yash Dayal                0        594.0
# Yashpal Singh            47        343.0
# Younis Khan               3        547.5
# Yuvraj Singh           2754         27.0
# Z Khan                  117        256.0
#
# [605 rows x 2 columns]

# %%
batter.set_index('batter_rank')
# Out:
#              batsman_run
# batter_rank
# 166.5                280
# 226.0                161
# 535.0                  4
# 329.0                 53
# 402.5                 25
# ...                  ...
# 594.0                  0
# 343.0                 47
# 547.5                  3
# 27.0                2754
# 256.0                117
#
# [605 rows x 1 columns]

# %%
batter.set_index('batter_rank',
                 append=True)
# Out:
#                             batsman_run
# batter         batter_rank
# A Ashish Reddy 166.5                280
# A Badoni       226.0                161
# A Chandila     535.0                  4
# A Chopra       329.0                 53
# A Choudhary    402.5                 25
# ...                                 ...
# Yash Dayal     594.0                  0
# Yashpal Singh  343.0                 47
# Younis Khan    547.5                  3
# Yuvraj Singh   27.0                2754
# Z Khan         256.0                117
#
# [605 rows x 1 columns]

# %% [markdown]
# #### 📦 **6. DataFrame.reset_index()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.reset_index.html#pandas-dataframe-reset-index)
#
# **Description :** Reset the index, or a level of it. Reset the index of the DataFrame, and use the default one instead. If the DataFrame has a MultiIndex, this method can remove one or more levels.
#
# **Note :** When you use `set_index()` method to set the index using existing column, by default, it removes previous index from it and set the new index. The problem can be solved by `reset_index()` method.

# %%
batter
# Out:
#                 batsman_run  batter_rank
# batter
# A Ashish Reddy          280        166.5
# A Badoni                161        226.0
# A Chandila                4        535.0
# A Chopra                 53        329.0
# A Choudhary              25        402.5
# ...                     ...          ...
# Yash Dayal                0        594.0
# Yashpal Singh            47        343.0
# Younis Khan               3        547.5
# Yuvraj Singh           2754         27.0
# Z Khan                  117        256.0
#
# [605 rows x 2 columns]

# %%
batter.reset_index()
# Out:
#              batter  batsman_run  batter_rank
# 0    A Ashish Reddy          280        166.5
# 1          A Badoni          161        226.0
# 2        A Chandila            4        535.0
# 3          A Chopra           53        329.0
# 4       A Choudhary           25        402.5
# ..              ...          ...          ...
# 600      Yash Dayal            0        594.0
# 601   Yashpal Singh           47        343.0
# 602     Younis Khan            3        547.5
# 603    Yuvraj Singh         2754         27.0
# 604          Z Khan          117        256.0
#
# [605 rows x 3 columns]

# %%
batter.reset_index().set_index('batter_rank')
# Out:
#                      batter  batsman_run
# batter_rank
# 166.5        A Ashish Reddy          280
# 226.0              A Badoni          161
# 535.0            A Chandila            4
# 329.0              A Chopra           53
# 402.5           A Choudhary           25
# ...                     ...          ...
# 594.0            Yash Dayal            0
# 343.0         Yashpal Singh           47
# 547.5           Younis Khan            3
# 27.0           Yuvraj Singh         2754
# 256.0                Z Khan          117
#
# [605 rows x 2 columns]

# %% [markdown]
# #### 📦 **7. DataFrame.rename()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html#pandas-dataframe-rename)
#
# **Description :** Rename columns or index labels. Function / dict values must be unique (1-to-1). Labels not contained in a dict / Series will be left as-is. Extra labels listed don’t throw an error.

# %% [markdown]
# #### 📦 **8. Series.unique()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.Series.unique.html#pandas-series-unique)
#
# **Description :** Return unique values of Series object. Uniques are returned in order of appearance.
#
# **Note :** It considers NaN values.

# %%
movies['wins_nominations'].unique()
# Out:
# array(['4 wins', nan, '17 wins & 1 nomination', '3 wins & 5 nominations',
#        '6 wins & 3 nominations', '1 win', '2 wins & 2 nominations',
#        '9 wins', '2 wins & 1 nomination', '1 nomination',
#        '3 wins & 6 nominations', '3 wins & 17 nominations',
#        '30 wins & 32 nominations', '4 wins & 9 nominations',
#        '2 wins & 3 nominations', '4 nominations', '3 wins & 1 nomination',
#        '3 wins & 9 nominations', '5 wins & 3 nominations',
#        '2 nominations', '21 wins & 26 nominations',
#        '9 wins & 7 nominations', '12 wins & 24 nominations',
#        '2 wins & 14 nominations', '3 wins & 3 nominations',
#        '5 nominations', '10 wins & 19 nominations',
#        '1 win & 1 nomination', '2 wins & 10 nominations',
#        '1 win & 8 nominations', '3 wins & 8 nominations',
#        '3 wins & 11 nominations', '1 win & 11 nominations',
#        '9 wins & 12 nominations', '24 wins & 25 nominations',
# ...

# %% [markdown]
# #### 📦 **9. DataFrame.nunique()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.nunique.html#pandas-dataframe-nunique)
#
# **Description :** Count number of distinct elements in specified axis. Return Series with number of distinct elements. Can ignore NaN values.
#
# **Note :** By default, it considers NaN values. (Can Ignore)

# %%
movies.nunique()
# Out:
# title_x             1625
# imdb_id             1623
# poster_path         1517
# wiki_link           1629
# title_y             1620
# original_title      1621
# is_adult               1
# year_of_release       19
# runtime              130
# genres               205
# imdb_rating           76
# imdb_votes          1267
# story               1603
# summary             1604
# tagline              553
# actors              1617
# wins_nominations     229
# release_date        1063
# dtype: int64

# %%
movies.nunique(dropna=False)
# Out:
# title_x             1625
# imdb_id             1623
# poster_path         1518
# wiki_link           1629
# title_y             1620
# original_title      1621
# is_adult               1
# year_of_release       19
# runtime              130
# genres               205
# imdb_rating           76
# imdb_votes          1267
# story               1604
# summary             1604
# tagline              554
# actors              1618
# wins_nominations     230
# release_date        1064
# dtype: int64

# %% [markdown]
# #### 📦 **10. DataFrame.isnull()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isnull.html#pandas-dataframe-isnull)
#
# **Description :** `DataFrame.isnull` is an alias for `DataFrame.isna`. Detect missing values.

# %%
students.isnull()
# Out:
#       IQ  MARKS  PACKAGE
# 0  False   True    False
# 1  False   True    False
# 2  False  False    False
# 3   True  False     True
# 4  False  False    False
# 5   True  False    False
# 6   True  False     True
# 7  False   True     True

# %% [markdown]
# #### 📦 **11. DataFrame.notnull()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.notnull.html#pandas-dataframe-notnull)
#
# **Description :** `DataFrame.notnull` is an alias for `DataFrame.notna`. Detect non-missing values.

# %%
students.notnull()
# Out:
#       IQ  MARKS  PACKAGE
# 0   True  False     True
# 1   True  False     True
# 2   True   True     True
# 3  False   True    False
# 4   True   True     True
# 5  False   True     True
# 6  False   True    False
# 7   True  False    False

# %% [markdown]
# #### 📦 **12. DataFrame.dropna()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html#pandas-dataframe-dropna)
#
# **Description :** Remove missing values.

# %%
students
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 3    NaN    NaN      NaN
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %%
students.dropna()
# Out:
#       IQ  MARKS  PACKAGE
# 2  140.0  200.0     80.0
# 4  160.0  220.0     90.0

# %%
students.dropna(how = 'all')
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %%
students.dropna(subset = ['IQ', 'PACKAGE'])
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 4  160.0  220.0     90.0
# 8  200.0    NaN    120.0

# %%
students.dropna(
    subset=['IQ', 'PACKAGE'],
    how='all'
)
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %% [markdown]
# #### 📦 **13. DataFrame.fillna()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html#pandas-dataframe-fillna)
#
# **Description :** Fill NA/NaN values using the specified method.
#
# **Note :** `method{‘backfill’, ‘bfill’, ‘ffill’, None}, default None` parameter of this method is deprecated since Version 2.1.0.

# %%
students
# Out:
#       IQ  MARKS  PACKAGE
# 0  100.0    NaN     60.0
# 1  120.0    NaN     70.0
# 2  140.0  200.0     80.0
# 3    NaN    NaN      NaN
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %%
students.fillna(
    value={
        'IQ': students['IQ'].mean(),
        'MARKS': students['MARKS'].mean(),
        'PACKAGE': students['PACKAGE'].mean()
    }
)
# Out:
#       IQ  MARKS     PACKAGE
# 0  100.0  240.0   60.000000
# 1  120.0  240.0   70.000000
# 2  140.0  200.0   80.000000
# 3  150.0  240.0   86.666667
# 4  160.0  220.0   90.000000
# 5  150.0  240.0  100.000000
# 6  150.0  260.0   86.666667
# 7  180.0  280.0   86.666667
# 8  200.0  240.0  120.000000

# %% [markdown]
# #### 📦 **14. DataFrame.drop_duplicates()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html#pandas-dataframe-drop-duplicates)
#
# **Description :** Return DataFrame with duplicate rows removed. Considering certain columns is optional. Indexes, including time indexes are ignored.
#
# **Note :** `subset` and `keep` parameter of this method are essential to learn.

# %%
students_df.drop_duplicates( 
    keep='last'
)
# Out:
#     IQ  MARKS  PACKAGE
# 0  100    200       60
# 1  120    220       70
# 2  140    240       80
# 3  160    260       90
# 5  180    280      100

# %% [markdown]
# ##### 🎯 **Q1. Find the last match played by Virat Kohli in Delhi.**

# %%
ipl_df['All Players'] = ipl_df['Team1Players'] + ipl_df['Team2Players']

# %%
def did_kohli_played(players):
    return 'V Kohli' in players

# %%
ipl_df['did_kohli_play'] = ipl_df['All Players'].apply(func=did_kohli_played)

# %%
ipl_df[(ipl_df['City'] == 'Delhi') & (ipl_df['did_kohli_play'] == True)].drop_duplicates(
    subset=['City', 'did_kohli_play'],
    keep='first'
)
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        All Players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_kohli_play
# 208           True
#
# [1 rows x 22 columns]

# %% [markdown]
# #### 📦 **15. DataFrame.drop()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop.html#pandas-dataframe-drop)
#
# **Description :** Drop specified labels from rows or columns.

# %% [markdown]
# Let's drop the `MARKS` column from `students` dataframe.

# %%
students.drop(
    labels='MARKS',
    axis=1
)
# Out:
#       IQ  PACKAGE
# 0  100.0     60.0
# 1  120.0     70.0
# 2  140.0     80.0
# 3    NaN      NaN
# 4  160.0     90.0
# 5    NaN    100.0
# 6    NaN      NaN
# 7  180.0      NaN
# 8  200.0    120.0

# %% [markdown]
# Dropping `MARKS` column from `students` dataframe can be done with another syntax too. Here it is...

# %%
students.drop(
    columns='MARKS'
)
# Out:
#       IQ  PACKAGE
# 0  100.0     60.0
# 1  120.0     70.0
# 2  140.0     80.0
# 3    NaN      NaN
# 4  160.0     90.0
# 5    NaN    100.0
# 6    NaN      NaN
# 7  180.0      NaN
# 8  200.0    120.0

# %% [markdown]
# Let's drop the first three rows from `students` dataframe.

# %%
students.drop(
    labels=[0,1,2],
    axis=0
)
# Out:
#       IQ  MARKS  PACKAGE
# 3    NaN    NaN      NaN
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %% [markdown]
# Similarly, it can be done in this way too...

# %%
students.drop(
    index=[0,1,2]
)
# Out:
#       IQ  MARKS  PACKAGE
# 3    NaN    NaN      NaN
# 4  160.0  220.0     90.0
# 5    NaN  240.0    100.0
# 6    NaN  260.0      NaN
# 7  180.0  280.0      NaN
# 8  200.0    NaN    120.0

# %% [markdown]
# #### 📦 **16. DataFrame.apply()**
#
# **Documentation Link :** [Link](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.apply.html#pandas-dataframe-apply)
#
# **Description :** Apply a function along an axis of the DataFrame.

# %%
def euclidean(row):
    p1 = row['Point1']
    p2 = row['Point2']
    return ((p1[0] - p2[0])**2 + (p1[1] - p2[1])**2)**0.5

# %%
points['Distance'] = points.apply(
    func=euclidean,
    axis=1
)
points
# Out:
#       Point1    Point2   Distance
# 0   (51, 92)  (90, 58)  51.739733
# 1   (14, 71)  (41, 91)  33.600595
# 2   (60, 20)  (59, 79)  59.008474
# 3   (82, 86)  (14, 61)  72.449983
# 4   (74, 74)  (61, 46)  30.870698
# 5   (87, 99)  (61, 50)  55.470713
# 6    (23, 2)  (54, 63)  68.425142
# 7   (21, 52)   (2, 50)  19.104973
# 8    (1, 87)   (6, 20)  67.186308
# 9   (29, 37)  (72, 38)  43.011626
# 10   (1, 63)   (17, 3)  62.096699
# 11  (59, 20)  (88, 59)  48.600412
# 12  (32, 75)   (13, 8)  69.641941
# 13  (57, 21)  (89, 52)  44.553339
# 14  (88, 48)   (1, 83)  93.776330
