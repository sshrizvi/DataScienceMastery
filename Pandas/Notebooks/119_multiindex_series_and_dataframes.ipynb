# %% [markdown]
# # **Article 119 : MultiIndex Series and DataFrames** [![Static Badge](https://img.shields.io/badge/Open%20in%20Colab%20-%20orange?style=plastic&logo=googlecolab&labelColor=grey)](https://colab.research.google.com/github/sshrizvi/DS-Python/blob/main/Pandas/Notebooks/119_multiindex_series_and_dataframes.ipynb)
#
# |🔴 **NOTE** 🔴|
# |:-----------:|
# |This notebook contains the practical implementations of the concepts discussed in the following article.|
# | Here is Article 119 - [MultiIndex Series and DataFrames](../Articles/119_multiindex_series_and_dataframes.md) |

# %% [markdown]
# ### 📦 **Importing Relevant Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 🚀 **Creating a MultiIndex Object**

# %% [markdown]
# #### **1. From Tuples**

# %%
multiindex_tuple = [
    ('USA', 'California'),
    ('USA', 'Texas'),
    ('India', 'Delhi'),
    ('India', 'Mumbai')
]

multiindex_obj_from_tuple = pd.MultiIndex.from_tuples(
    tuples = multiindex_tuple,
    names = ['Country', 'State']
)

multiindex_obj_from_tuple
# Out:
# MultiIndex([(  'USA', 'California'),
#             (  'USA',      'Texas'),
#             ('India',      'Delhi'),
#             ('India',     'Mumbai')],
#            names=['Country', 'State'])

# %% [markdown]
# #### **2. From Product**

# %%
countries = ['New York', 'Los Angeles', 'Chicago']
products = ['Laptop', 'Smartphone', 'Tablet']

multiindex_obj_from_prod = pd.MultiIndex.from_product(
    iterables = [countries, products],
    names = ['Country', 'Product']
)

multiindex_obj_from_prod
# Out:
# MultiIndex([(   'New York',     'Laptop'),
#             (   'New York', 'Smartphone'),
#             (   'New York',     'Tablet'),
#             ('Los Angeles',     'Laptop'),
#             ('Los Angeles', 'Smartphone'),
#             ('Los Angeles',     'Tablet'),
#             (    'Chicago',     'Laptop'),
#             (    'Chicago', 'Smartphone'),
#             (    'Chicago',     'Tablet')],
#            names=['Country', 'Product'])

# %% [markdown]
# #### **3. From Arrays**

# %%
arrays = [
    [1, 1, 2, 2],
    ['red', 'blue', 'red', 'blue']
]

multiindex_obj_from_arrays = pd.MultiIndex.from_arrays(
    arrays = arrays,
    names=('number', 'color')
)

multiindex_obj_from_arrays
# Out:
# MultiIndex([(1,  'red'),
#             (1, 'blue'),
#             (2,  'red'),
#             (2, 'blue')],
#            names=['number', 'color'])

# %% [markdown]
# ### 🚀 **Creating a MultiIndex Series**

# %%
units_sold = np.array(
    object = [100, 200, 300, 110, 210, 310, 120, 220, 320]
)

product_sales_series = pd.Series(
    data = units_sold,
    name = 'Units Sold',
    index = multiindex_obj_from_prod
)

product_sales_series
# Out:
# Country      Product
# New York     Laptop        100
#              Smartphone    200
#              Tablet        300
# Los Angeles  Laptop        110
#              Smartphone    210
#              Tablet        310
# Chicago      Laptop        120
#              Smartphone    220
#              Tablet        320
# Name: Units Sold, dtype: int32

# %% [markdown]
# ### 📦 **Stacking**
# **Method :** `pandas.DataFrame.stack(...)`

# %% [markdown]
# #### **1. Stacking Single-Level Column**

# %% [markdown]
# ##### ⚠️ **Example Data**

# %%
df = pd.DataFrame(
    data = {
    'Math': [85, 90],
    'Science': [88, 92]
    },
    index = pd.Index(['Alice', 'Bob'],
    name='Name')
)

df
# Out:
#        Math  Science
# Name
# Alice    85       88
# Bob      90       92

# %% [markdown]
# ##### ⚡ **Implementation**

# %%
df.stack()
# Out:
# Name
# Alice  Math       85
#        Science    88
# Bob    Math       90
#        Science    92
# dtype: int64

# %% [markdown]
# #### **2. Stacking MultiIndex Column**

# %% [markdown]
# ##### ⚠️ **Example Data**

# %%
products = ['Laptop', 'Smartphone']
quarters = ['Q1', 'Q2']
metrics = ['Units Sold', 'Revenue']

multi_col = pd.MultiIndex.from_product(
    iterables = [products, quarters, metrics],
    names = ['Product', 'Quarter', 'Metric']
)

np.random.seed(42)
data = np.random.randint(
    low = 100,
    high = 1000,
    size = (5, len(multi_col))
)

multi_col_df = pd.DataFrame(
    data = data,
    columns = multi_col,
    index = ['Store A', 'Store B', 'Store C', 'Store D', 'Store E']
)

multi_col_df
# Out:
# Product     Laptop                            Smartphone                     \
# Quarter         Q1                 Q2                 Q1                 Q2
# Metric  Units Sold Revenue Units Sold Revenue Units Sold Revenue Units Sold
# Store A        202     535        960     370        206     171        800
# Store B        714     221        566     314        430     558        187
# Store C        199     971        763     230        761     408        869
# Store D        591     513        905     485        291     376        260
# Store E        413     121        352     847        956     660        574
#
# Product
# Quarter
# Metric  Revenue
# Store A     120
# Store B     472
# Store C     443
# Store D     559
# Store E     158

# %% [markdown]
# ##### ⚡ **Implementation**

# %%
multi_col_df.stack(
    future_stack = True
)
# Out:
# Product            Laptop      Smartphone
# Quarter                Q1   Q2         Q1   Q2
#         Metric
# Store A Units Sold    202  960        206  800
#         Revenue       535  370        171  120
# Store B Units Sold    714  566        430  187
#         Revenue       221  314        558  472
# Store C Units Sold    199  763        761  869
#         Revenue       971  230        408  443
# Store D Units Sold    591  905        291  260
#         Revenue       513  485        376  559
# Store E Units Sold    413  352        956  574
#         Revenue       121  847        660  158

# %%
multi_col_df.stack(
    level = 0,
    future_stack = True
)
# Out:
# Quarter                    Q1                 Q2
# Metric             Units Sold Revenue Units Sold Revenue
#         Product
# Store A Laptop            202     535        960     370
#         Smartphone        206     171        800     120
# Store B Laptop            714     221        566     314
#         Smartphone        430     558        187     472
# Store C Laptop            199     971        763     230
#         Smartphone        761     408        869     443
# Store D Laptop            591     513        905     485
#         Smartphone        291     376        260     559
# Store E Laptop            413     121        352     847
#         Smartphone        956     660        574     158

# %%
multi_col_df.stack(
    level ='Quarter',
    future_stack = True
)
# Out:
# Product             Laptop         Smartphone
# Metric          Units Sold Revenue Units Sold Revenue
#         Quarter
# Store A Q1             202     535        206     171
#         Q2             960     370        800     120
# Store B Q1             714     221        430     558
#         Q2             566     314        187     472
# Store C Q1             199     971        761     408
#         Q2             763     230        869     443
# Store D Q1             591     513        291     376
#         Q2             905     485        260     559
# Store E Q1             413     121        956     660
#         Q2             352     847        574     158

# %%
multi_col_df.stack(
    level = [0,1],
    future_stack = True
)
# Out:
# Metric                      Units Sold  Revenue
#         Product    Quarter
# Store A Laptop     Q1              202      535
#                    Q2              960      370
#         Smartphone Q1              206      171
#                    Q2              800      120
# Store B Laptop     Q1              714      221
#                    Q2              566      314
#         Smartphone Q1              430      558
#                    Q2              187      472
# Store C Laptop     Q1              199      971
#                    Q2              763      230
#         Smartphone Q1              761      408
#                    Q2              869      443
# Store D Laptop     Q1              591      513
#                    Q2              905      485
#         Smartphone Q1              291      376
#                    Q2              260      559
# Store E Laptop     Q1              413      121
#                    Q2              352      847
#         Smartphone Q1              956      660
#                    Q2              574      158

# %% [markdown]
# ### 📦 **Unstacking**
# **Method :** `pandas.DataFrame.unstack(...)`

# %% [markdown]
# #### **1. Unstacking Single-Level Index**

# %% [markdown]
# ##### ⚠️ **Example Data**

# %%
df = pd.DataFrame(
    data = {
    'Math': [85, 90],
    'Science': [88, 92]
    },
    index = pd.Index(['Alice', 'Bob'],
    name='Name')
)

df
# Out:
#        Math  Science
# Name
# Alice    85       88
# Bob      90       92

# %% [markdown]
# ##### ⚡ **Implementation**

# %%
df.unstack()
# Out:
#          Name
# Math     Alice    85
#          Bob      90
# Science  Alice    88
#          Bob      92
# dtype: int64

# %% [markdown]
# #### **2. Unstacking MultiIndex Index**

# %% [markdown]
# ##### ⚠️ **Example Data**

# %%
cities = ['New York', 'Los Angeles', 'Chicago']
years = [2022, 2023]

index = pd.MultiIndex.from_product(
    iterables = [cities, years],
    names = ['City', 'Year']
)

np.random.seed(42)
data = {
    'Laptop Sales': np.random.randint(100, 1000, size=len(index)),
    'Smartphone Sales': np.random.randint(100, 1000, size=len(index)),
    'Tablet Sales': np.random.randint(100, 1000, size=len(index))
}

multi_index_df = pd.DataFrame(
    data = data,
    index = index
)

multi_index_df
# Out:
#                   Laptop Sales  Smartphone Sales  Tablet Sales
# City        Year
# New York    2022           202               800           430
#             2023           535               120           558
# Los Angeles 2022           960               714           187
#             2023           370               221           472
# Chicago     2022           206               566           199
#             2023           171               314           971

# %% [markdown]
# ##### ⚡ **Implementation**

# %%
multi_index_df.unstack()
# Out:
#             Laptop Sales      Smartphone Sales      Tablet Sales
# Year                2022 2023             2022 2023         2022 2023
# City
# Chicago              206  171              566  314          199  971
# Los Angeles          960  370              714  221          187  472
# New York             202  535              800  120          430  558

# %%
multi_index_df.unstack(
    level = 0
)
# Out:
#      Laptop Sales                      Smartphone Sales                       \
# City      Chicago Los Angeles New York          Chicago Los Angeles New York
# Year
# 2022          206         960      202              566         714      800
# 2023          171         370      535              314         221      120
#
#      Tablet Sales
# City      Chicago Los Angeles New York
# Year
# 2022          199         187      430
# 2023          971         472      558

# %%
multi_index_df.unstack(
    level = [0, 1]
)
# Out:
#                   City         Year
# Laptop Sales      New York     2022    202
#                                2023    535
#                   Los Angeles  2022    960
#                                2023    370
#                   Chicago      2022    206
#                                2023    171
# Smartphone Sales  New York     2022    800
#                                2023    120
#                   Los Angeles  2022    714
#                                2023    221
#                   Chicago      2022    566
#                                2023    314
# Tablet Sales      New York     2022    430
#                                2023    558
#                   Los Angeles  2022    187
#                                2023    472
#                   Chicago      2022    199
#                                2023    971
# dtype: int32

# %%
multi_index_df.unstack().unstack()
# Out:
#                   Year  City
# Laptop Sales      2022  Chicago        206
#                         Los Angeles    960
#                         New York       202
#                   2023  Chicago        171
#                         Los Angeles    370
#                         New York       535
# Smartphone Sales  2022  Chicago        566
#                         Los Angeles    714
#                         New York       800
#                   2023  Chicago        314
#                         Los Angeles    221
#                         New York       120
# Tablet Sales      2022  Chicago        199
#                         Los Angeles    187
#                         New York       430
#                   2023  Chicago        971
#                         Los Angeles    472
#                         New York       558
# dtype: int32

# %% [markdown]
# ### 🚀 **MultiIndex DataFrame**

# %% [markdown]
# #### 📌 **Creating a MultiIndex DataFrame**

# %% [markdown]
# ##### **Example 1**

# %%
regions = ['North', 'South']
stores = ['Store A', 'Store B']
years = [2022, 2023]

index = pd.MultiIndex.from_product(
    iterables = [regions, stores, years],
    names = ['Region', 'Store', 'Year']
)

data = {
    'Total Sales ($)': np.random.randint(50000, 200000, size=len(index)),
    'Profit ($)': np.random.randint(5000, 30000, size=len(index)),
    'Units Sold': np.random.randint(1000, 10000, size=len(index)),
}

df1 = pd.DataFrame(
    data = data,
    index = index
)

df1
# Out:
#                      Total Sales ($)  Profit ($)  Units Sold
# Region Store   Year
# North  Store A 2022            66023       10051        8849
#                2023            91090       11420        3047
#        Store B 2022           117221       22568        3747
#                2023           114820       25939        1189
# South  Store A 2022            50769       24769        3734
#                2023           109735       11396        4005
#        Store B 2022           114925       13666        5658
#                2023            55311       23942        2899

# %% [markdown]
# ##### **Example 2**

# %%
departments = ['CSE', 'ECE']
semesters = ['Sem 1', 'Sem 2']
subjects = ['Maths', 'DSA', 'Python']

index = pd.MultiIndex.from_product(
    iterables = [departments, semesters, subjects],
    names = ['Department', 'Semester', 'Subject']
)

data = {
    'Average Score': np.random.randint(50, 90, size=len(index)),
    'Highest Score': np.random.randint(85, 100, size=len(index)),
    'Pass Percentage': np.random.randint(70, 100, size=len(index))
}

df2 = pd.DataFrame(
    data = data,
    index = index
)

df2
# Out:
#                              Average Score  Highest Score  Pass Percentage
# Department Semester Subject
# CSE        Sem 1    Maths               52             89               83
#                     DSA                 86             86               86
#                     Python              56             88               73
#            Sem 2    Maths               70             96               87
#                     DSA                 58             99               77
#                     Python              88             96               73
# ECE        Sem 1    Maths               67             91               71
#                     DSA                 53             96               99
#                     Python              74             97               75
#            Sem 2    Maths               63             92               91
#                     DSA                 58             99               79
#                     Python              75             87               73

# %% [markdown]
# ##### **Example 3**

# %%
hospitals = ['Hospital A', 'Hospital B']
departments = ['Cardiology', 'Neurology']
patients = ['P001', 'P002']
row_index = pd.MultiIndex.from_product([hospitals, departments, patients], names=['Hospital', 'Department', 'Patient ID'])

years = [2022, 2023]
metrics = ['Blood Pressure', 'Cholesterol']
checkups = ['Initial', 'Final']
col_index = pd.MultiIndex.from_product([years, metrics, checkups], names=['Year', 'Metric', 'Checkup'])

data = np.random.randint(
    low = 70,
    high = 180,
    size = (len(row_index), len(col_index))
)

df3 = pd.DataFrame(
    data = data,
    index = row_index,
    columns = col_index
)

df3
# Out:
# Year                                       2022                          \
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123   162         132    87
#                       P002                  131   169          83   164
#            Neurology  P001                  156   131         109   154
#                       P002                   93    95         158   129
# Hospital B Cardiology P001                  114   134         158   140
#                       P002                   77   157         132    80
#            Neurology  P001                  102    74         175   172
#                       P002                  141    81         103   102
#
# Year                                       2023
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  159   113         103   143
#                       P002                  117    84         141   147
#            Neurology  P001                  149   178         151   122
#                       P002                  178   110          98    84
# Hospital B Cardiology P001                   78   157          70   177
#                       P002                  150    77         104   104
#            Neurology  P001                  110    97          76   142
#                       P002                  117    92         131   157

# %% [markdown]
# #### 📌 **Accessing Columns in a MultiIndex DataFrame**

# %%
df1['Profit ($)']
# Out:
# Region  Store    Year
# North   Store A  2022    10051
#                  2023    11420
#         Store B  2022    22568
#                  2023    25939
# South   Store A  2022    24769
#                  2023    11396
#         Store B  2022    13666
#                  2023    23942
# Name: Profit ($), dtype: int32

# %%
type(df1['Profit ($)'])
# Out:
# pandas.core.series.Series

# %%
df3[2022]
# Out:
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123   162         132    87
#                       P002                  131   169          83   164
#            Neurology  P001                  156   131         109   154
#                       P002                   93    95         158   129
# Hospital B Cardiology P001                  114   134         158   140
#                       P002                   77   157         132    80
#            Neurology  P001                  102    74         175   172
#                       P002                  141    81         103   102

# %%
df3[2022]['Blood Pressure']
# Out:
# Checkup                           Initial  Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001            123    162
#                       P002            131    169
#            Neurology  P001            156    131
#                       P002             93     95
# Hospital B Cardiology P001            114    134
#                       P002             77    157
#            Neurology  P001            102     74
#                       P002            141     81

# %%
df3[(2022, 'Blood Pressure')]
# Out:
# Checkup                           Initial  Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001            123    162
#                       P002            131    169
#            Neurology  P001            156    131
#                       P002             93     95
# Hospital B Cardiology P001            114    134
#                       P002             77    157
#            Neurology  P001            102     74
#                       P002            141     81

# %%
df3[2022]['Blood Pressure']['Initial']
# Out:
# Hospital    Department  Patient ID
# Hospital A  Cardiology  P001          123
#                         P002          131
#             Neurology   P001          156
#                         P002           93
# Hospital B  Cardiology  P001          114
#                         P002           77
#             Neurology   P001          102
#                         P002          141
# Name: Initial, dtype: int32

# %% [markdown]
# **Extracting The *Initial Values* Column of Health Metrics Using Slicing**

# %%
df3.loc[:,(2022, 'Blood Pressure'):(2023, 'Cholesterol'):2]
# Out:
# Year                                       2022                       2023  \
# Metric                           Blood Pressure Cholesterol Blood Pressure
# Checkup                                 Initial     Initial        Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123         132            159
#                       P002                  131          83            117
#            Neurology  P001                  156         109            149
#                       P002                   93         158            178
# Hospital B Cardiology P001                  114         158             78
#                       P002                   77         132            150
#            Neurology  P001                  102         175            110
#                       P002                  141         103            117
#
# Year
# Metric                           Cholesterol
# Checkup                              Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103
#                       P002               141
#            Neurology  P001               151
#                       P002                98
# Hospital B Cardiology P001                70
#                       P002               104
#            Neurology  P001                76
#                       P002               131

# %% [markdown]
# #### 📌 **Accessing Rows in a MultiIndex DataFrame**
#
# **Use loc[ ] or iloc[ ] for accessing rows**

# %%
df1.loc['North']
# Out:
#               Total Sales ($)  Profit ($)  Units Sold
# Store   Year
# Store A 2022            66023       10051        8849
#         2023            91090       11420        3047
# Store B 2022           117221       22568        3747
#         2023           114820       25939        1189

# %%
df1.loc['North'].loc['Store A']
# Out:
#       Total Sales ($)  Profit ($)  Units Sold
# Year
# 2022            66023       10051        8849
# 2023            91090       11420        3047

# %%
df1.loc[('North', 'Store A')]
# Out:
#       Total Sales ($)  Profit ($)  Units Sold
# Year
# 2022            66023       10051        8849
# 2023            91090       11420        3047

# %% [markdown]
# **Showing only *2022* data**

# %%
df1.iloc[::2]
# Out:
#                      Total Sales ($)  Profit ($)  Units Sold
# Region Store   Year
# North  Store A 2022            66023       10051        8849
#        Store B 2022           117221       22568        3747
# South  Store A 2022            50769       24769        3734
#        Store B 2022           114925       13666        5658

# %% [markdown]
# #### 📌 **Accessing Both Rows and Columns in a MultiIndex DataFrame**

# %% [markdown]
# **Accessing Alternate Rows and All Columns**

# %%
df1.iloc[0::2]
# Out:
#                      Total Sales ($)  Profit ($)  Units Sold
# Region Store   Year
# North  Store A 2022            66023       10051        8849
#        Store B 2022           117221       22568        3747
# South  Store A 2022            50769       24769        3734
#        Store B 2022           114925       13666        5658

# %% [markdown]
# **Accessing All Rows and Alternate Columns**

# %%
df1.iloc[::,0::2]
# Out:
#                      Total Sales ($)  Units Sold
# Region Store   Year
# North  Store A 2022            66023        8849
#                2023            91090        3047
#        Store B 2022           117221        3747
#                2023           114820        1189
# South  Store A 2022            50769        3734
#                2023           109735        4005
#        Store B 2022           114925        5658
#                2023            55311        2899

# %%
df3.loc[:, 0::2]
# Out:
# Year                                       2022                       2023  \
# Metric                           Blood Pressure Cholesterol Blood Pressure
# Checkup                                 Initial     Initial        Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123         132            159
#                       P002                  131          83            117
#            Neurology  P001                  156         109            149
#                       P002                   93         158            178
# Hospital B Cardiology P001                  114         158             78
#                       P002                   77         132            150
#            Neurology  P001                  102         175            110
#                       P002                  141         103            117
#
# Year
# Metric                           Cholesterol
# Checkup                              Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103
#                       P002               141
#            Neurology  P001               151
#                       P002                98
# Hospital B Cardiology P001                70
#                       P002               104
#            Neurology  P001                76
#                       P002               131

# %%
df3.loc[:,(2022, 'Blood Pressure'):(2023, 'Cholesterol'):2]
# Out:
# Year                                       2022                       2023  \
# Metric                           Blood Pressure Cholesterol Blood Pressure
# Checkup                                 Initial     Initial        Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123         132            159
#                       P002                  131          83            117
#            Neurology  P001                  156         109            149
#                       P002                   93         158            178
# Hospital B Cardiology P001                  114         158             78
#                       P002                   77         132            150
#            Neurology  P001                  102         175            110
#                       P002                  141         103            117
#
# Year
# Metric                           Cholesterol
# Checkup                              Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103
#                       P002               141
#            Neurology  P001               151
#                       P002                98
# Hospital B Cardiology P001                70
#                       P002               104
#            Neurology  P001                76
#                       P002               131

# %% [markdown]
# **Accessing Initial Values Metric for *P001* only**

# %%
df3.iloc[0::2, 0::2]
# Out:
# Year                                       2022                       2023  \
# Metric                           Blood Pressure Cholesterol Blood Pressure
# Checkup                                 Initial     Initial        Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123         132            159
#            Neurology  P001                  156         109            149
# Hospital B Cardiology P001                  114         158             78
#            Neurology  P001                  102         175            110
#
# Year
# Metric                           Cholesterol
# Checkup                              Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103
#            Neurology  P001               151
# Hospital B Cardiology P001                70
#            Neurology  P001                76

# %%
df3.loc[
    ('Hospital A', 'Cardiology', 'P001')::2,
    (2022, 'Blood Pressure')::2
]
# Out:
# Year                                       2022                       2023  \
# Metric                           Blood Pressure Cholesterol Blood Pressure
# Checkup                                 Initial     Initial        Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123         132            159
#            Neurology  P001                  156         109            149
# Hospital B Cardiology P001                  114         158             78
#            Neurology  P001                  102         175            110
#
# Year
# Metric                           Cholesterol
# Checkup                              Initial
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103
#            Neurology  P001               151
# Hospital B Cardiology P001                70
#            Neurology  P001                76

# %% [markdown]
# #### 📌 **Sorting in a MultiIndex DataFrame**

# %% [markdown]
# **Sorting Data such that *P002* appears at the TOP**

# %%
df3.sort_index(
    axis = 0,
    level = ['Patient ID'],
    ascending = False
)
# Out:
# Year                                       2022                          \
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital B Neurology  P002                  141    81         103   102
#            Cardiology P002                   77   157         132    80
# Hospital A Neurology  P002                   93    95         158   129
#            Cardiology P002                  131   169          83   164
# Hospital B Neurology  P001                  102    74         175   172
#            Cardiology P001                  114   134         158   140
# Hospital A Neurology  P001                  156   131         109   154
#            Cardiology P001                  123   162         132    87
#
# Year                                       2023
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital B Neurology  P002                  117    92         131   157
#            Cardiology P002                  150    77         104   104
# Hospital A Neurology  P002                  178   110          98    84
#            Cardiology P002                  117    84         141   147
# Hospital B Neurology  P001                  110    97          76   142
#            Cardiology P001                   78   157          70   177
# Hospital A Neurology  P001                  149   178         151   122
#            Cardiology P001                  159   113         103   143

# %% [markdown]
# **Sorting Data such that 2023 year appears first**

# %%
df3.sort_index(
    axis = 1,
    level = 'Year',
    ascending = False
)
# Out:
# Year                                    2023                             \
# Metric                           Cholesterol       Blood Pressure
# Checkup                              Initial Final        Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103   143            159   113
#                       P002               141   147            117    84
#            Neurology  P001               151   122            149   178
#                       P002                98    84            178   110
# Hospital B Cardiology P001                70   177             78   157
#                       P002               104   104            150    77
#            Neurology  P001                76   142            110    97
#                       P002               131   157            117    92
#
# Year                                    2022
# Metric                           Cholesterol       Blood Pressure
# Checkup                              Initial Final        Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001               132    87            123   162
#                       P002                83   164            131   169
#            Neurology  P001               109   154            156   131
#                       P002               158   129             93    95
# Hospital B Cardiology P001               158   140            114   134
#                       P002               132    80             77   157
#            Neurology  P001               175   172            102    74
#                       P002               103   102            141    81

# %% [markdown]
# #### 📦 **Transpose**

# %%
df3.transpose()
# Out:
# Hospital                    Hospital A                     Hospital B       \
# Department                  Cardiology      Neurology      Cardiology
# Patient ID                        P001 P002      P001 P002       P001 P002
# Year Metric         Checkup
# 2022 Blood Pressure Initial        123  131       156   93        114   77
#                     Final          162  169       131   95        134  157
#      Cholesterol    Initial        132   83       109  158        158  132
#                     Final           87  164       154  129        140   80
# 2023 Blood Pressure Initial        159  117       149  178         78  150
#                     Final          113   84       178  110        157   77
#      Cholesterol    Initial        103  141       151   98         70  104
#                     Final          143  147       122   84        177  104
#
# Hospital
# Department                  Neurology
# Patient ID                       P001 P002
# Year Metric         Checkup
# 2022 Blood Pressure Initial       102  141
#                     Final          74   81
#      Cholesterol    Initial       175  103
#                     Final         172  102
# 2023 Blood Pressure Initial       110  117
#                     Final          97   92
#      Cholesterol    Initial        76  131
#                     Final         142  157

# %%
df3.T
# Out:
# Hospital                    Hospital A                     Hospital B       \
# Department                  Cardiology      Neurology      Cardiology
# Patient ID                        P001 P002      P001 P002       P001 P002
# Year Metric         Checkup
# 2022 Blood Pressure Initial        123  131       156   93        114   77
#                     Final          162  169       131   95        134  157
#      Cholesterol    Initial        132   83       109  158        158  132
#                     Final           87  164       154  129        140   80
# 2023 Blood Pressure Initial        159  117       149  178         78  150
#                     Final          113   84       178  110        157   77
#      Cholesterol    Initial        103  141       151   98         70  104
#                     Final          143  147       122   84        177  104
#
# Hospital
# Department                  Neurology
# Patient ID                       P001 P002
# Year Metric         Checkup
# 2022 Blood Pressure Initial       102  141
#                     Final          74   81
#      Cholesterol    Initial       175  103
#                     Final         172  102
# 2023 Blood Pressure Initial       110  117
#                     Final          97   92
#      Cholesterol    Initial        76  131
#                     Final         142  157

# %% [markdown]
# #### 📦 **Swaplevel**

# %%
df3.swaplevel()
# Out:
# Year                                       2022                          \
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Patient ID Department
# Hospital A P001       Cardiology            123   162         132    87
#            P002       Cardiology            131   169          83   164
#            P001       Neurology             156   131         109   154
#            P002       Neurology              93    95         158   129
# Hospital B P001       Cardiology            114   134         158   140
#            P002       Cardiology             77   157         132    80
#            P001       Neurology             102    74         175   172
#            P002       Neurology             141    81         103   102
#
# Year                                       2023
# Metric                           Blood Pressure       Cholesterol
# Checkup                                 Initial Final     Initial Final
# Hospital   Patient ID Department
# Hospital A P001       Cardiology            159   113         103   143
#            P002       Cardiology            117    84         141   147
#            P001       Neurology             149   178         151   122
#            P002       Neurology             178   110          98    84
# Hospital B P001       Cardiology             78   157          70   177
#            P002       Cardiology            150    77         104   104
#            P001       Neurology             110    97          76   142
#            P002       Neurology             117    92         131   157

# %%
df3.swaplevel(
    axis = 1
)
# Out:
# Year                                       2022                             \
# Checkup                                 Initial          Final     Initial
# Metric                           Blood Pressure Blood Pressure Cholesterol
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123            162         132
#                       P002                  131            169          83
#            Neurology  P001                  156            131         109
#                       P002                   93             95         158
# Hospital B Cardiology P001                  114            134         158
#                       P002                   77            157         132
#            Neurology  P001                  102             74         175
#                       P002                  141             81         103
#
# Year                                                   2023                 \
# Checkup                                Final        Initial          Final
# Metric                           Cholesterol Blood Pressure Blood Pressure
# Hospital   Department Patient ID
# Hospital A Cardiology P001                87            159            113
#                       P002               164            117             84
#            Neurology  P001               154            149            178
#                       P002               129            178            110
# Hospital B Cardiology P001               140             78            157
#                       P002                80            150             77
#            Neurology  P001               172            110             97
#                       P002               102            117             92
#
# Year
# Checkup                              Initial       Final
# Metric                           Cholesterol Cholesterol
# Hospital   Department Patient ID
# Hospital A Cardiology P001               103         143
#                       P002               141         147
#            Neurology  P001               151         122
#                       P002                98          84
# Hospital B Cardiology P001                70         177
#                       P002               104         104
#            Neurology  P001                76         142
#                       P002               131         157

# %%
df3.swaplevel(
    axis = 1,
    i = 'Year',
    j = 'Metric'
)
# Out:
# Metric                           Blood Pressure       Cholesterol        \
# Year                                       2022              2022
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  123   162         132    87
#                       P002                  131   169          83   164
#            Neurology  P001                  156   131         109   154
#                       P002                   93    95         158   129
# Hospital B Cardiology P001                  114   134         158   140
#                       P002                   77   157         132    80
#            Neurology  P001                  102    74         175   172
#                       P002                  141    81         103   102
#
# Metric                           Blood Pressure       Cholesterol
# Year                                       2023              2023
# Checkup                                 Initial Final     Initial Final
# Hospital   Department Patient ID
# Hospital A Cardiology P001                  159   113         103   143
#                       P002                  117    84         141   147
#            Neurology  P001                  149   178         151   122
#                       P002                  178   110          98    84
# Hospital B Cardiology P001                   78   157          70   177
#                       P002                  150    77         104   104
#            Neurology  P001                  110    97          76   142
#                       P002                  117    92         131   157

# %% [markdown]
# ### 🚀 **Long Format V/S Wide Format Data**

# %% [markdown]
# #### ⚠️ **Data Warning**

# %% [markdown]
# ##### **Reading Data into DataFrames**

# %%
covid19_global_deaths = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/time_series_covid19_deaths_global.csv'
)

# %%
covid19_global_confirmed = pd.read_csv(
    filepath_or_buffer = '../Resources/Data/time_series_covid19_confirmed_global.csv'
)

# %% [markdown]
# #### 📦 **Melt Function**
# Converts Wide Format to Long Format

# %%
covid19_global_confirmed.melt()
# Out:
#               variable   value
# 0       Province/State     NaN
# 1       Province/State     NaN
# 2       Province/State     NaN
# 3       Province/State     NaN
# 4       Province/State     NaN
# ...                ...     ...
# 312404          1/2/23  703228
# 312405          1/2/23     535
# 312406          1/2/23   11945
# 312407          1/2/23  334661
# 312408          1/2/23  259981
#
# [312409 rows x 2 columns]

# %%
covid19_global_deaths.melt()
# Out:
#               variable value
# 0       Province/State   NaN
# 1       Province/State   NaN
# 2       Province/State   NaN
# 3       Province/State   NaN
# 4       Province/State   NaN
# ...                ...   ...
# 312404          1/2/23  5708
# 312405          1/2/23     0
# 312406          1/2/23  2159
# 312407          1/2/23  4024
# 312408          1/2/23  5637
#
# [312409 rows x 2 columns]

# %%
unpivoted_covid19_global_confirmed = covid19_global_confirmed.melt(
    id_vars = ['Province/State', 'Country/Region', 'Lat', 'Long'],
    var_name = 'Date',
    value_name = 'Num_Of_Confirmed'
)
unpivoted_covid19_global_confirmed
# Out:
#        Province/State        Country/Region        Lat        Long     Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         Num_Of_Confirmed
# 0                      0
# 1                      0
# 2                      0
# 3                      0
# 4                      0
# ...                  ...
# 311248            703228
# 311249               535
# 311250             11945
# 311251            334661
# 311252            259981
#
# [311253 rows x 6 columns]

# %%
unpivoted_covid19_global_deaths = covid19_global_deaths.melt(
    id_vars = ['Province/State', 'Country/Region', 'Lat', 'Long'],
    var_name = 'Date',
    value_name = 'Num_Of_Deaths'
)
unpivoted_covid19_global_deaths
# Out:
#        Province/State        Country/Region        Lat        Long     Date  \
# 0                 NaN           Afghanistan  33.939110   67.709953  1/22/20
# 1                 NaN               Albania  41.153300   20.168300  1/22/20
# 2                 NaN               Algeria  28.033900    1.659600  1/22/20
# 3                 NaN               Andorra  42.506300    1.521800  1/22/20
# 4                 NaN                Angola -11.202700   17.873900  1/22/20
# ...               ...                   ...        ...         ...      ...
# 311248            NaN    West Bank and Gaza  31.952200   35.233200   1/2/23
# 311249            NaN  Winter Olympics 2022  39.904200  116.407400   1/2/23
# 311250            NaN                 Yemen  15.552727   48.516388   1/2/23
# 311251            NaN                Zambia -13.133897   27.849332   1/2/23
# 311252            NaN              Zimbabwe -19.015438   29.154857   1/2/23
#
#         Num_Of_Deaths
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ...               ...
# 311248           5708
# 311249              0
# 311250           2159
# 311251           4024
# 311252           5637
#
# [311253 rows x 6 columns]

# %% [markdown]
# The below code finds out datewise Confirmed and Death Cases Count of each Country.

# %%
pd.merge(
    left = unpivoted_covid19_global_confirmed,
    right = unpivoted_covid19_global_deaths,
    on = ['Province/State', 'Country/Region', 'Lat', 'Long', 'Date'],
    how = 'inner'
)[['Country/Region', 'Date', 'Num_Of_Confirmed', 'Num_Of_Deaths']]
# Out:
#               Country/Region     Date  Num_Of_Confirmed  Num_Of_Deaths
# 0                Afghanistan  1/22/20                 0              0
# 1                    Albania  1/22/20                 0              0
# 2                    Algeria  1/22/20                 0              0
# 3                    Andorra  1/22/20                 0              0
# 4                     Angola  1/22/20                 0              0
# ...                      ...      ...               ...            ...
# 311248    West Bank and Gaza   1/2/23            703228           5708
# 311249  Winter Olympics 2022   1/2/23               535              0
# 311250                 Yemen   1/2/23             11945           2159
# 311251                Zambia   1/2/23            334661           4024
# 311252              Zimbabwe   1/2/23            259981           5637
#
# [311253 rows x 4 columns]
